# %%
# %%javascript
# MathJax.Hub.Config({
#     TeX: { equationNumbers: { autoNumber: "AMS" } }
# });

# %% [markdown]
# # Variational inference for a simple one parameter linear model
#
# ### Basics
#
# VI (see [Blei et al 2018](https://arxiv.org/abs/1601.00670)) is a way of turning the approximation of a posterior distribution, $p(\theta | D)$, from a sampling problem (ie using MCMC) into an optimization problem. The advantage of doing this is that we can build an approximate distribution more quickly via optimization. The disadvantage is often a poorer approximation in many cases (specifically, we have to choose the form of the approximation and so misspecification at this stage cannot be overcome even asymptotically, unlike most sampling methods).
#
# VI aims to find the distribution closest to the posterior according to the Kullback-Leibler divergence
# $$q^*(\theta) = \arg \min_q KL(q(\theta) || p(\theta | D))$$
# We usually restrict $q$ to lie in some parametric family of distributions, ie, $q=q_\phi$, and then find
# $$\phi^* = \arg \min_\phi KL(q_\phi(\theta) || p(\theta | D))$$
#
# We can't compute this directly, but by noting that
#
# \begin{align*}
# KL(q_\phi(\theta) || p(\theta | D)) &= \mathbb{E}_{\theta \sim q} (\log q(\theta) - \log p(\theta | D))\\
# &= \mathbb{E}_{\theta \sim q} \log q(\theta) - \mathbb{E}_{\theta \sim q} \log p(\theta, D) + \log p(D)
# \end{align*}
#
# we can see that minimizing the KL is equivalent to maximizing
# \begin{equation}
# \mathcal{L}(\phi) = \mathbb{E} \log p(\theta, D) - \mathbb{E} \log q_\phi(\theta)
# \end{equation}
# where all expectations are with respect to $\theta \sim q_\phi(\theta)$. $\mathcal{L}$ is called the evidence lower bound (ELBO).
#
#
# An equivalent expression that will be useful is
# \begin{equation}
# \mathcal{L} = \mathbb{E} \log p(D|\theta) - KL(q(\theta)|| p(\theta))
# \end{equation}
# ie, the ELBO is a trade-off between minimizing the expected log-likelihood of the data under $q$ whilst not moving too far from the prior distribution $p(\theta)$. It is a balance between fitting the data, and taking account of the prior.

# %% [markdown]
# ### Linear model
#
#
# ### REWRITE THIS!!!!!!@!!!!!
#
# Consider the simple linear model
# $$y = X\beta+ e \qquad e \sim N_n(0, I)$$
# with prior distribution $\beta \sim N_n(0, 100 I)$, where $X$ is a $n \times p$ design matrix, $y$ a $n$ vector of observations, and $\beta$ a p-vector of parameters to be learnt.
#
#
# Can the posterior can be computed exactly in this case?
#
# We'll now consider variational inference for this model. We will use  Gaussian  distributions as the variational family
# $$q_\phi(\beta) = N(\mu, D)$$
# where $D={diag}(\sigma^2_i)$ is a diagonal matrix of variances.
# We thus have $2p$ variational parameters to learn. We'll arrange these into a $p \times 2$ matrix with $i^{th}$ row $\phi_{i.}=(\mu_i, \log \sigma_i^2)$. We use $\log \sigma^2$ to avoid problems with negative variances. Note that the variational family is of the correct parametric form, so that VI should give us the exact posterior distribution in this case (ie $q^* = p(\theta|D)$ if we do everything correctly).

# %% [markdown]
# We want to choose $\phi$ to maximize the ELBO
# $$\mathcal{L}(\phi) = \mathbb{E}_{\beta\sim q_\phi} \log p(y|X,\beta)- KL(q_\phi(\beta)||p(\beta))$$
# For this model, we have
# $$\log p(y|x,a) \propto -\frac{1}{2} (y-X\beta)^\top(y-X\beta) = -\frac{1}{2} (y -X\mu+X\mu -X\beta)^\top (y -X\mu+X\mu -X\beta)$$
# where we've ignored terms that don't depend on the variational parameters (as they won't matter when we maximize). Expanding and taking the expectation wrt $q$, the cross-terms are zero, so we get
# $$\mathbb{E}_{\beta\sim q} \log p(y|X,\beta) = -\frac{1}{2}(y-X\mu)^\top(y-X\mu)  -\frac{1}{2}\mathbb{E}(\beta-\mu)^\top X^\top X(\beta-\mu) $$
#
# To compute the term on the right, note that $X(\beta-\mu)\sim N(0, XDX^\top)$. We can then use the formula for the expectation of a [quadratic form](https://en.wikipedia.org/wiki/Quadratic_form_(statistics)) to see that
# the expected value is $tr(XDX^\top) = tr(DX^\top X)$. Thus
#
# $$\mathbb{E}_{\beta\sim q} \log p(y|X,\beta) = -\frac{1}{2}(y-X\mu)^\top(y-X\mu) -\frac{1}{2}tr(D X^\top X) $$
#
#
# For two univariate Gaussian distributions it is easy to show
# $$KL(N(\mu_1, \sigma^2_1)|| N(\mu_2, \sigma^2_2)) = -\frac{1}{2}\log \frac{\sigma_1^2}{\sigma_2^2}+\frac{\sigma_1^2+(\mu_1-\mu_2)^2}{2\sigma_2^2}-\frac{1}{2}$$
# and so
# $$KL(N_p(\mu, diag(\sigma^2_i))|| N_p(0, 100I)) = -\frac{1}{2}\sum_{i=1}^p\log\sigma_i^2+\sum \frac{\sigma^2_i + \mu_i^2}{200}$$
# where I have ignored terms that will disappear when we differentiate in order to maximize.

# %% [markdown]
# #### Analytic VI
#
# If we differentiate $\mathcal{L}$ with respect to $mu$ and set the derivative equal to zero we find
# $$X^\top(y-X\mu) - \mu/100=0$$ which gives
# $$\mu^* = (X^\top X+\frac{1}{100} I)^{-1} X^\top y$$
#
# To differentiate wrt $\sigma^2$ we have to first note that (using Einstein's summation convention)
# $$\frac{\partial}{\partial \sigma^2_i}tr(DX^\top X) = \frac{\partial}{\partial \sigma^2_i} D_{ij}X_{kj}X_{ki} = X_{ki}X_{ki}$$
# so
# $$\frac{\partial}{\partial \sigma^2}tr(DX^\top X) = diag(X^\top X)$$
#
# Differentiating the ELBO wrt to $\sigma^2_i$ gives
# $$-\frac{1}{2} diag(X^\top X)_i +\frac{1}{2\sigma^2_i}-\frac{1}{200}=0$$
# which then gives
# $$\sigma^{2*}_i = \frac{1}{diag(X^\top X)_i + 1/100}$$

# %% [markdown]
# The Hessian is
# $$H = (\begin{array}{cc}X^\top X +\frac{1}{100}I_{p\times p} &0 \\
# 0&\frac{1}{2}D^{-2}\end{array})
# $$

# %% [markdown]
# ## VI in practice
# This calculation required three steps that may be difficult for more realistic models.
#
# 1. Computation of $\mathbb{E}_{\theta \sim q_\phi(\theta)} \log p(D|\theta )$
# 2. Computation of $KL(q_\phi(\theta)||p(\theta))$
# 3. Optimization of the ELBO wrt variational parameters $\phi$.
#
# Problem 2 doesn't occur as often as 1 and 3, as the prior distribution and variational family are  usually  choosen to be simple forms allowing us to compute the KL divergence analytically.

# %% [markdown]
# ### Using jax autodiff to do the optimization
#
# Let's first assume that we can compute the ELBO analytically, and that the optimization (problem 3) is hard. We can use an autodiff language such as jax to help with the optimization of the ELBO. Here I'll use [jax](https://github.com/google/jax). Jax does a number of cool things in addition to autodiff, including just in time compilation which we'll make use of to speed up the code.

# %%
import jax.numpy as np
from jax import grad, jit, random, vmap, jit
from scipy.stats import norm
import numpy as onp
key = random.PRNGKey(1)
# Out:
# /Users/pmzrdw/opt/anaconda3/lib/python3.7/site-packages/jax/lib/xla_bridge.py:122: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %% [markdown]
# Let's create some data to use, and compute the true posterior distribution.

# %%
n=100
X2 = norm.rvs(size=(n,2))*2
X2=np.concatenate((np.ones(n)[:,None], X2), axis=1)

# %%
#import matplotlib.pyplot as plt
#from scipy.stats import norm # should I use jax random numbers?
#x = norm.rvs(size=n)*2
betatrue = np.array((1.,2.,3.))
y= X2@betatrue+ norm.rvs(size=n)
#plt.plot(x,y, '+')

# True posterior?
y.shape
# Out:
# (100,)

# %% [markdown]
# Let's first optimize using scipy's built in optimization function. This doesn't use anything other than evaluations of the ELBO (ie it doesn't use derivative information).

# %%
from jax import jacfwd, jacrev,  value_and_grad
def hessian(f):
    return jacfwd(jacrev(f))

# %% [markdown]
# ## Tidy VAE code
#
# To make the code look more like standard VAE code we can write it in terms of a encoder and decoder.

# %%
class VAE():
    def __init__(self, x, y, phi0=None):
        ''' 
        x must be 2-d array with one row per observation, one column per covariate. If leading column isn't a column
        of 1s then we add one.
        
        y is 1-d array with same number of rows of x
        
        phi0 is 2-d array with p rows and 2 columns. Each row correspondsto one parameter. The first column is the 
        parameter mean, the second column is the parameter log-variance.  The first row corresponds to the intercept, 
        the subsequent rows are ordered as per the columns of x.
        '''
    
        assert x.ndim==2
        assert y.ndim==1
        self.n = x.shape[0] ## number of observations
       
        assert y.size==self.n
        if np.all(x[:,0]!=1): ## append column of 1s.
            x = np.concatenate((np.ones(self.n)[:,None], x), axis=1)
        
        self.p = x.shape[1] ## number of parameters
        self.x = x
        self.y = y
        if phi0 is None:
            phi0 = np.zeros((self.p,2))  #  better to make this random
            #one row for each regression parameter. First column is mean, second is logvar
        self.encoder(phi0)
        self.form_derivs()  ## initialise the gradients of the loss
        
    def encoder(self, phi):
        ## what should this do? not currently being used.
        '''Encoder using a gaussian distribution with parameters mu and logvar'''
        self.phi=phi
        self.mu = phi[:,0] # how to do this for general dimension?
        self.logvar = phi[:,1]
        
        self.var=np.exp(self.logvar)
        self.sd=np.exp(self.logvar/2.)
        return(None) 
    
    def print(self, key=None):
        print('--------------------------------')
        print('Mean of the parameter distributions: mu =', self.mu)
        print('Var of the parameter distributions: sigma^2 =', self.var)
        print('Std deviation of the parameter distributions: sigma =', self.sd)
        print('phi =', self.phi)
        if key is not None:
            print('loss=', model.loss(self.phi, 10000, key))
        print('---------------------------------')
        
    def reparam(self, e):
        '''
        Reparametrization trick - converts an array of S x p N(0,1) rvs into an array of S x p theta values
        self.sd is a 1d array of length p
        e * self.sd multiplies each row of e by vector of std devs. Note this is element wise not matrix multiplication
        self.mu is a 1d array of length p. Adding it to the S x p matrix seesms to broadcase in the right way.
        '''
        return(self.mu+e*self.sd)
        
    
    def decoder(self, theta):
        ''' 
        model prediction given theta
        theta must be a p-vector
        '''
        assert theta.ndim ==1
        return(self.x @ theta) # model prediction is y=theta*x
    
    def loglike(self, theta):
        '''
        loglikelihood - upto proportionality ignoring variance component - given theta
        '''
        assert theta.ndim==1
        return(-0.5*np.sum((self.y-self.decoder(theta))**2))  
    
    def kld(self, phi):
        '''
        phi = (mean, log(var))
        
        kld(N(mu, var), N(0,100)) is
        -0.5 x logvar+0.5 x log(100)+(var+mu^2)/200 - 0.5
        but as we are maximizing this we don't care about terms that don't contain parameters, so we return
        -0.5 log var+(var+mu^2)/200.
        
        CHANGE to take any allow any variance?
        '''
        assert phi.ndim==1
        assert phi.size==2
        return(-0.5* phi[1]+(np.exp(phi[1]) + phi[0]**2)/200.)
        
    def loss(self, phi, S, key):
        assert phi.shape == self.phi.shape
        self.encoder(phi) #IS THIS A BAD IDEA
        print('warning - encoder run - possibly bad idea')
        kld = np.sum(vmap(self.kld)(self.phi))  
        esamples=random.normal(key, shape=(S,self.p))
        thetasamples = self.reparam(esamples)
        Eloglike = np.mean(vmap(self.loglike)(thetasamples)) # apply loglike to each row of thetasamples and take mean
        return(kld-Eloglike)
    
    def form_derivs(self):
        self.dloss = value_and_grad(self.loss)
        self.hessian=hessian(self.loss)

# %% [markdown]
# ### COMPUTE THE TRUE DERIVS

# %%
#from jax.test_util import check_grads
#check_grads(model.loss, (phi, subkey), order=1)

# %%
class AnalyticModel():
    def __init__(self, X, y, phi0=None):
        ''' 
        x must be 2-d array with one row per observation, one column per covariate. If leading column isn't a column
        of 1s then we add one.
        
        y is 1-d array with same number of rows of x
        
        phi0 is 2-d array with p rows and 2 columns. Each row correspondsto one parameter. The first column is the 
        parameter mean, the second column is the parameter log-variance.  The first row corresponds to the intercept, 
        the subsequent rows are ordered as per the columns of x.
        '''
    
        assert X.ndim==2
        assert y.ndim==1
        self.n = X.shape[0] ## number of observations
       
        assert y.size==self.n
        if np.all(X[:,0]!=1): ## append column of 1s.
            X = np.concatenate((np.ones(self.n)[:,None], X), axis=1)
        
        self.p = X.shape[1] ## number of parameters
        self.X = X
        self.y = y
        if phi0 is None:
            phi0 = np.zeros((self.p,2))  #  better to make this random
            #one row for each regression parameter. First column is mean, second is logvar
        self.encoder(phi0)
        self.OLS()
        self.VI()
        
    def encoder(self, phi):
        '''
        Encoder takes phi values and computes variance etc
        '''
        self.phi=phi
        self.mu = phi[:,0] # how to do this for general dimension?
        self.logvar = phi[:,1]
        self.var=np.exp(self.logvar)
        self.sd=np.exp(self.logvar/2.)
        self.D = np.diag(self.var)
        return(None) 
    
    def print(self):
        print('-----------  AnalyticModel Summary---------------------')
        print('Mean of the parameter distributions: mu =', self.mu)
        print('Var of the parameter distributions: sigma^2 =', self.var)
        print('Std deviation of the parameter distributions: sigma =', self.sd)
        print('phi =', self.phi)
        print('loss=', self.expectedloss(self.phi))
        print('---------------------------------')

    def expectedloss(self, phi):
        assert phi.shape == self.phi.shape
        logvar = phi[:,1]
        mu = phi[:,0]
        D = np.diag(np.exp(logvar))
        kld = -0.5*np.sum(logvar)+1./200. * np.sum(np.exp(logvar)+mu**2)     
        Eloglike = -0.5*(self.y-self.X @ mu).T @ (self.y-self.X@ mu) - 0.5*np.trace(D @ self.X.T @ self.X)
        return(kld-Eloglike)

    def dexpectedloss(self, phi):# hand coded derivatives for comparison
        print('warning - dexpected loss not coded gradients for sigma')
        dmu = -self.X.T @(self.y[:,None]- self.X @ phi[:,0][:,None])+phi[:,0][:,None]/100.
        # I'd have to compute deriv of log sigma2 for other derivs 
        return(dmu)
        
    def hessian_analyticloss(self, phi):
        H = onp.zeros((2*self.p, 2*self.p))
        H[0:self.p, 0:self.p] = -1.*(-self.X.T@self.X - 1./100 * onp.eye(self.p))
        H[self.p:, self.p:] = 0.5* np.diag(self.var**(-2))
        return(H)
    
    def OLS(self):
        self.betahat = np.linalg.inv(self.X.T @ self.X) @ self.X.T @self.y
        #print('Least squares parameter estimate= ', betahat)
        self.cov_betahat = np.linalg.inv(self.X.T @ self.X)
        #print('marginal variance estimates = ', onp.diag(cov_betahat))
        #print('full cov matrix=',cov_betahat)
        self.RSS = np.sum((self.y-self.X@ self.betahat)**2)
        #print('Residual error=fitted sum of squares = ', )
        
    def Bayes(self):
        pass
    
    def printOLS(self):
        print('---------- OLS summary -------------')
        print('Least squares parameter estimate= ', self.betahat)
        print('marginal variance estimates = ', onp.diag(self.cov_betahat))
        print('Residual sum of squares=', self.RSS)
        print('------------------------------------')


    def VI(self):
        self.mustar = np.linalg.inv(self.X.T @ self.X+1./100. * np.eye(self.p)) @ self.X.T @ self.y
        self.sigma2star = 1./(np.diag(self.X.T @ self.X)+1./100.) 
        self.phistar = np.concatenate((self.mustar[:,None], np.log(self.sigma2star)[:,None]), axis=1)
        self.lossstar= self.expectedloss(self.phistar)
                              
                            
    def printVI(self):
        print('---------- VI summary -------------')
        print('Optimal variational estimates of mu= ', self.mustar)
        print('Optimal variational estimates of sigma^2 = ', self.sigma2star)
        print('Optimal variational loss =', self.lossstar)
         print('Optimal phi =', self.phistar)
        print('------------------------------------')
# Out:
#   File "<ipython-input-54-c25d3f0ea1c5>", line 106
#     print('Optimal phi =', self.phistar)
#     ^
# IndentationError: unexpected indent

# %%
mod = AnalyticModel(X2, y)
mod.print()
mod.printOLS()
mod.printVI()
print(mod.hessian_analyticloss(mod.phi))
mod.print()
# Out:
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0. 0. 0.]
# Var of the parameter distributions: sigma^2 = [1. 1. 1.]
# Std deviation of the parameter distributions: sigma = [1. 1. 1.]
# phi = [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# loss= 2708.9182
# ---------------------------------
# ---------- OLS summary -------------
# Least squares parameter estimate=  [0.9051655 1.9661201 2.9989383]
# marginal variance estimates =  [0.01042778 0.00258431 0.00298595]
# Residual sum of squares= 79.2222
# ------------------------------------
# ---------- VI summary -------------
# Optimal variational estimates of mu=  [0.90504336 1.9660599  2.9988465 ]
# Optimal variational estimates of sigma^2 =  [0.009999   0.0024832  0.00297975]
# Optimal variational loss = 49.389194
# ------------------------------------
# [[100.01000214 -39.67985916  -8.28479385   0.           0.
#     0.        ]
#  [-39.67985916 402.70645142   2.52183342   0.           0.
#     0.        ]
#  [ -8.28479385   2.52183342 335.59915161   0.           0.
#     0.        ]
#  [  0.           0.           0.           0.5          0.
#     0.        ]
#  [  0.           0.           0.           0.           0.5
#     0.        ]
#  [  0.           0.           0.           0.           0.
#     0.5       ]]
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0. 0. 0.]
# Var of the parameter distributions: sigma^2 = [1. 1. 1.]
# Std deviation of the parameter distributions: sigma = [1. 1. 1.]
# phi = [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# loss= 2708.9182
# ---------------------------------

# %%
key, subkey = random.split(key)
model = VAE(X2, y)
phi = model.phi

print(model.loss(phi, 100000, subkey))
print(mod.expectedloss(phi))
# Out:
# warning - encoder run - possibly bad idea
# 2712.4988
# 2708.9182

# %%
model = VAE(X2, y)
#print(dphi_vae(phi, subkey))
#model.form_derivs()

phi = model.phi

h=0.0001

numerical_deriv = onp.zeros(phi.shape)
S=100000
for ii in range(phi.shape[0]):
    eps=onp.zeros(phi.shape)
    eps[ii,0]=1*h
    numerical_deriv[ii,0]=(model.loss(phi+eps, S, subkey)-model.loss(phi-eps,S, subkey))/(2.*h)
    eps=onp.zeros(phi.shape)
    eps[ii,1]=1*h
    numerical_deriv[ii,1]=(model.loss(phi+eps, S, subkey)-model.loss(phi-eps,S, subkey))/(2.*h)
    

print(numerical_deriv)
print(model.dloss(phi, 1000,subkey))
#print(dphi_vae2(phi, model, subkey, 1000))
print(mod.dexpectedloss(phi))

#Gradients wrong.
#GRADIENTS from dphi_vae aren't changing with S. Something wrong
# Out:
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# [[   15.86914062    47.60742188]
#  [ -764.16015625   200.1953125 ]
#  [-1008.30078125   168.45703125]]
# warning - encoder run - possibly bad idea
# (DeviceArray(2684.5686, dtype=float32), DeviceArray([[  13.859123,   51.51314 ],
#              [-765.5476  ,  206.27069 ],
#              [-994.12134 ,  148.71306 ]], dtype=float32))
# [[   12.344415]
#  [ -763.39557 ]
#  [-1003.87024 ]]

# %%
print(phi, phi.shape)

print('----- check losses ------', )
print('vae loss', model.loss(phi, 10000, subkey))
print('analytic loss', mod.expectedloss(phi))

print('----- check gradients ------', )
print('jax gradients', model.dloss(phi, 10000, subkey))
print(' analytic gradients', mod.dexpectedloss(phi))

print('----- check Hessians ------', )
H = model.hessian(phi, 1000,subkey)
print(model.hessian(phi, 1000,subkey)) # note the Hessian is independent of theta. So we could just estimate 
print(mod.hessian_analyticloss(phi))
# it once with large S and then fix it???

# To do NR we'd need to flatten phi, grad and H into vectors and a matrix respectively.
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]] (3, 2)
# ----- check losses ------
# warning - encoder run - possibly bad idea
# vae loss 2715.7659
# analytic loss 2708.9182
# ----- check gradients ------
# warning - encoder run - possibly bad idea
# jax gradients (DeviceArray(2715.7659, dtype=float32), DeviceArray([[   13.288932,    48.871048],
#              [ -766.2276  ,   202.3207  ],
#              [-1004.88794 ,   169.43141 ]], dtype=float32))
# warning - dexpected loss not coded gradients for sigma
#  analytic gradients [[   12.344415]
#  [ -763.39557 ]
#  [-1003.87024 ]]
# ----- check Hessians ------
# warning - encoder run - possibly bad idea
# warning - encoder run - possibly bad idea
# [[[[ 1.00009926e+02 -1.29319489e-01]
#    [-3.96798744e+01  2.33834624e-01]
#    [-8.28479385e+00 -1.45824298e-01]]
#
#   [[-1.29320741e-01  5.26735954e+01]
#    [ 5.13143018e-02  6.77597940e-01]
#    [ 1.07139498e-02  4.36454192e-02]]]
#
#
#  [[[-3.96798744e+01  5.13141230e-02]
#    [ 4.02706543e+02 -2.37310171e+00]
#    [ 2.52183962e+00  4.43879403e-02]]
#
#   [[ 2.33834505e-01  6.77598059e-01]
#    [-2.37310076e+00  2.12633392e+02]
#    [-1.48612689e-02 -1.14571285e-02]]]
#
#
#  [[[-8.28479290e+00  1.07139219e-02]
#    [ 2.52183962e+00 -1.48613416e-02]
#    [ 3.35599335e+02  5.90685272e+00]]
#
#   [[-1.45824313e-01  4.36454304e-02]
#    [ 4.43880074e-02 -1.14571294e-02]
#    [ 5.90685368e+00  1.52108490e+02]]]]
# [[100.01000214 -39.67985916  -8.28479385   0.           0.
#     0.        ]
#  [-39.67985916 402.70645142   2.52183342   0.           0.
#     0.        ]
#  [ -8.28479385   2.52183342 335.59915161   0.           0.
#     0.        ]
#  [  0.           0.           0.           0.5          0.
#     0.        ]
#  [  0.           0.           0.           0.           0.5
#     0.        ]
#  [  0.           0.           0.           0.           0.
#     0.5       ]]

# %% [markdown]
# ### Optimizing the analytic ELBO
#
# Before we train using the vae, let's do the computation with the analytic values.

# %%
from scipy.optimize import minimize

def niceloss(flatphi):
    phi=onp.zeros((3,2))
    phi[0,:]=flatphi[0:2]
    phi[1,:]= flatphi[2:4]
    phi[2,:]=flatphi[4:6]
    return(mod.expectedloss(phi))

phi=np.array(((1,2),(3,4),(5,6)))
phi
phi.flatten()
niceloss(phi.flatten())


optout = minimize(niceloss, phi,method='Nelder-Mead', tol=1e-6)
flatphiopt=optout.x
phiopt = onp.zeros(phi.shape)
phiopt[0,:]=flatphiopt[0:2]
phiopt[1,:]= flatphiopt[2:4]
phiopt[2,:]=flatphiopt[4:6]
print(phiopt)
mod.printVI()
# Out:
# [[ 0.90510395 -4.60452739]
#  [ 1.9660015  -5.99703879]
#  [ 2.99888843 -5.81606696]]
# ---------- VI summary -------------
# Optimal variational estimates of mu=  [0.90504336 1.9660599  2.9988465 ]
# Optimal variational estimates of sigma^2 =  [0.009999   0.0024832  0.00297975]
# Optimal variational loss = 49.389194
# ------------------------------------

# %%
mod = AnalyticModel(X2, y)
dloss= grad(mod.expectedloss)

obj=1000
dobj=1000

gamma=0.001
phi=mod.phi
print('Phi0', phi)

S=5000
while dobj >10e-3:
    mod.print()
    obj_new = mod.expectedloss(phi)
    gra = dloss(phi)
    phinew = phi - gamma *  gra
    phi=phinew
    mod.encoder(phi)
    
    dobj = np.abs(obj-obj_new)
    obj=obj_new
    print('objective=',obj, ', change in objective=', dobj)
    print('--------')

phiGD=phi
print(phiGD)
print(mod.phistar)
print(mod.lossstar)


#Why dont we get the right variances?
# Out:
# Phi0 [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0. 0. 0.]
# Var of the parameter distributions: sigma^2 = [1. 1. 1.]
# Std deviation of the parameter distributions: sigma = [1. 1. 1.]
# phi = [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# loss= 2708.9182
# ---------------------------------
# objective= 2708.9182 , change in objective= 1708.9182
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [-0.01234442  0.7633954   1.0038704 ]
# Var of the parameter distributions: sigma^2 = [0.9517004  0.8180325  0.84594613]
# Std deviation of the parameter distributions: sigma = [0.9755513 0.9044515 0.9197533]
# phi = [[-0.01234442 -0.049505  ]
#  [ 0.7633954  -0.20085323]
#  [ 1.0038704  -0.16729958]]
# loss= 1342.4023
# ---------------------------------
# objective= 1342.4023 , change in objective= 1366.5159
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.01515401 1.2163454  1.6688151 ]
# Var of the parameter distributions: sigma^2 = [0.9079238 0.6941503 0.7343651]
# Std deviation of the parameter distributions: sigma = [0.9528504  0.8331568  0.85695106]
# phi = [[ 0.01515401 -0.09659478]
#  [ 1.2163454  -0.3650667 ]
#  [ 1.6688151  -0.308749  ]]
# loss= 764.3058
# ---------------------------------
# objective= 764.3058 , change in objective= 578.09656
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.06338425 1.4863038  2.1096907 ]
# Var of the parameter distributions: sigma^2 = [0.86805904 0.6039064  0.6495502 ]
# Std deviation of the parameter distributions: sigma = [0.9316969  0.77711415 0.80594677]
# phi = [[ 0.06338425 -0.14149551]
#  [ 1.4863038  -0.5043361 ]
#  [ 2.1096907  -0.43147516]]
# loss= 507.50122
# ---------------------------------
# objective= 507.50122 , change in objective= 256.80457
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.12115546 1.6483501  2.4023275 ]
# Var of the parameter distributions: sigma^2 = [0.8316008  0.5350288  0.58276606]
# Std deviation of the parameter distributions: sigma = [0.91192144 0.73145664 0.76339114]
# phi = [[ 0.12115546 -0.18440281]
#  [ 1.6483501  -0.62543464]
#  [ 2.4023275  -0.53996944]]
# loss= 384.93842
# ---------------------------------
# objective= 384.93842 , change in objective= 122.562805
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.18200336 1.7466936  2.5968256 ]
# Var of the parameter distributions: sigma^2 = [0.7981274 0.4806267 0.5287406]
# Std deviation of the parameter distributions: sigma = [0.8933798  0.6932725  0.72714555]
# phi = [[ 0.18200336 -0.22548701]
#  [ 1.7466936  -0.7326644 ]
#  [ 2.5968256  -0.63725734]]
# loss= 320.35757
# ---------------------------------
# objective= 320.35757 , change in objective= 64.58084
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.2422795 1.8073575 2.7263064]
# Var of the parameter distributions: sigma^2 = [0.7672847  0.4365117  0.48409227]
# Std deviation of the parameter distributions: sigma = [0.8759479 0.6606903 0.6957674]
# phi = [[ 0.2422795  -0.26489738]
#  [ 1.8073575  -0.82894015]
#  [ 2.7263064  -0.7254798 ]]
# loss= 282.0199
# ---------------------------------
# objective= 282.0199 , change in objective= 38.337677
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.30000728 1.845657   2.81268   ]
# Var of the parameter distributions: sigma^2 = [0.73877233 0.39998302 0.44654715]
# Std deviation of the parameter distributions: sigma = [0.85951865 0.6324421  0.66824186]
# phi = [[ 0.30000728 -0.30276546]
#  [ 1.845657   -0.9163332 ]
#  [ 2.81268    -0.8062103 ]]
# loss= 256.3753
# ---------------------------------
# objective= 256.3753 , change in objective= 25.644592
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.35419703 1.8706058  2.8704484 ]
# Var of the parameter distributions: sigma^2 = [0.7123344  0.36921686 0.41451725]
# Std deviation of the parameter distributions: sigma = [0.8439991  0.60763216 0.6438301 ]
# phi = [[ 0.35419703 -0.33920777]
#  [ 1.8706058  -0.9963711 ]
#  [ 2.8704484  -0.8806407 ]]
# loss= 237.43932
# ---------------------------------
# objective= 237.43932 , change in objective= 18.93599
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.40443578 1.8875121  2.9092157 ]
# Var of the parameter distributions: sigma^2 = [0.6877513  0.34293512 0.38685843]
# Std deviation of the parameter distributions: sigma = [0.8293077  0.58560663 0.6219795 ]
# phi = [[ 0.40443578 -0.37432805]
#  [ 1.8875121  -1.070214  ]
#  [ 2.9092157  -0.9496965 ]]
# loss= 222.44112
# ---------------------------------
# objective= 222.44112 , change in objective= 14.998199
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.45064223 1.8995059  2.9353464 ]
# Var of the parameter distributions: sigma^2 = [0.66483325 0.3202142  0.3627247 ]
# Std deviation of the parameter distributions: sigma = [0.81537306 0.56587476 0.6022663 ]
# phi = [[ 0.45064223 -0.40821904]
#  [ 1.8995059  -1.1387651 ]
#  [ 2.9353464  -1.0141112 ]]
# loss= 210.01135
# ---------------------------------
# objective= 210.01135 , change in objective= 12.429764
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.49291995 1.9084371  2.9530602 ]
# Var of the parameter distributions: sigma^2 = [0.64341587 0.30036968 0.34147656]
# Std deviation of the parameter distributions: sigma = [0.80213207 0.54805994 0.58435994]
# phi = [[ 0.49291995 -0.440964  ]
#  [ 1.9084371  -1.2027413 ]
#  [ 2.9530602  -1.0744762 ]]
# loss= 199.4141
# ---------------------------------
# objective= 199.4141 , change in objective= 10.5972595
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.5314706 1.9154047 2.965157 ]
# Var of the parameter distributions: sigma^2 = [0.6233557  0.28288308 0.32262135]
# Std deviation of the parameter distributions: sigma = [0.7895288 0.5318675 0.5679977]
# phi = [[ 0.5314706 -0.472638 ]
#  [ 1.9154047 -1.2627217]
#  [ 2.965157  -1.1312759]]
# loss= 190.21367
# ---------------------------------
# objective= 190.21367 , change in objective= 9.200424
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.5665425 1.9210656 2.973496 ]
# Var of the parameter distributions: sigma^2 = [0.60452706 0.26735416 0.3057732 ]
# Std deviation of the parameter distributions: sigma = [0.7775134  0.517063   0.55296767]
# phi = [[ 0.5665425 -0.5033089]
#  [ 1.9210656 -1.3191811]
#  [ 2.973496  -1.1849116]]
# loss= 182.12642
# ---------------------------------
# objective= 182.12642 , change in objective= 8.08725
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.5984006 1.9258174 2.9793127]
# Var of the parameter distributions: sigma^2 = [0.58681935 0.25346902 0.29062536]
# Std deviation of the parameter distributions: sigma = [0.76604134 0.50345707 0.5390968 ]
# phi = [[ 0.5984006  -0.53303826]
#  [ 1.9258174  -1.3725137 ]
#  [ 2.9793127  -1.2357203 ]]
# loss= 174.95241
# ---------------------------------
# objective= 174.95241 , change in objective= 7.174011
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.62730926 1.929905   2.9834292 ]
# Var of the parameter distributions: sigma^2 = [0.570135   0.24097781 0.27693096]
# Std deviation of the parameter distributions: sigma = [0.75507283 0.4908949  0.5262423 ]
# phi = [[ 0.62730926 -0.56188214]
#  [ 1.929905   -1.4230504 ]
#  [ 2.9834292  -1.283987  ]]
# loss= 168.5419
# ---------------------------------
# objective= 168.5419 , change in objective= 6.410507
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.6535231 1.9334834 2.9863935]
# Var of the parameter distributions: sigma^2 = [0.55438733 0.22967912 0.2644889 ]
# Std deviation of the parameter distributions: sigma = [0.7445719  0.4792485  0.51428485]
# phi = [[ 0.6535231  -0.58989173]
#  [ 1.9334834  -1.4710721 ]
#  [ 2.9863935  -1.3299559 ]]
# loss= 162.77794
# ---------------------------------
# objective= 162.77794 , change in objective= 5.763962
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.67728186 1.9366533  2.988571  ]
# Var of the parameter distributions: sigma^2 = [0.5394992  0.21940877 0.2531338 ]
# Std deviation of the parameter distributions: sigma = [0.73450613 0.4684109  0.50312406]
# phi = [[ 0.67728186 -0.6171139 ]
#  [ 1.9366533  -1.5168188 ]
#  [ 2.988571   -1.3738371 ]]
# loss= 157.56691
# ---------------------------------
# objective= 157.56691 , change in objective= 5.211029
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.6988083 1.9394839 2.9902065]
# Var of the parameter distributions: sigma^2 = [0.525402   0.21003157 0.24272823]
# Std deviation of the parameter distributions: sigma = [0.72484624 0.458292   0.49267456]
# phi = [[ 0.6988083 -0.6435915]
#  [ 1.9394839 -1.5604974]
#  [ 2.9902065 -1.4158128]]
# loss= 152.83234
# ---------------------------------
# objective= 152.83234 , change in objective= 4.7345734
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.7183078 1.9420247 2.9914644]
# Var of the parameter distributions: sigma^2 = [0.512034   0.20143513 0.23315716]
# Std deviation of the parameter distributions: sigma = [0.7155655  0.44881526 0.48286352]
# phi = [[ 0.7183078 -0.6693643]
#  [ 1.9420247 -1.6022879]
#  [ 2.9914644 -1.4560425]]
# loss= 148.51094
# ---------------------------------
# objective= 148.51094 , change in objective= 4.321396
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.73596835 1.9443128  2.9924552 ]
# Var of the parameter distributions: sigma^2 = [0.49933976 0.19352522 0.22432347]
# Std deviation of the parameter distributions: sigma = [0.70663977 0.439915   0.47362798]
# phi = [[ 0.73596835 -0.69446856]
#  [ 1.9443128  -1.6423475 ]
#  [ 2.9924552  -1.4946662 ]]
# loss= 144.55008
# ---------------------------------
# objective= 144.55008 , change in objective= 3.9608612
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.75196165 1.9463778  2.9932542 ]
# Var of the parameter distributions: sigma^2 = [0.48726943 0.18622226 0.21614459]
# Std deviation of the parameter distributions: sigma = [0.69804686 0.43153477 0.46491355]
# phi = [[ 0.75196165 -0.71893805]
#  [ 1.9463778  -1.6808144 ]
#  [ 2.9932542  -1.5318077 ]]
# loss= 140.90532
# ---------------------------------
# objective= 140.90532 , change in objective= 3.6447601
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.766444  1.9482437 2.9939122]
# Var of the parameter distributions: sigma^2 = [0.47577798 0.17945857 0.20854996]
# Std deviation of the parameter distributions: sigma = [0.68976665 0.42362553 0.4566727 ]
# phi = [[ 0.766444   -0.74280393]
#  [ 1.9482437  -1.7178109 ]
#  [ 2.9939122  -1.5675766 ]]
# loss= 137.53918
# ---------------------------------
# objective= 137.53918 , change in objective= 3.3661346
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.7795575 1.9499313 2.9944649]
# Var of the parameter distributions: sigma^2 = [0.46482456 0.17317626 0.20147876]
# Std deviation of the parameter distributions: sigma = [0.68178046 0.41614452 0.44886386]
# phi = [[ 0.7795575 -0.7660952]
#  [ 1.9499313 -1.7534454]
#  [ 2.9944649 -1.6020713]]
# loss= 134.41982
# ---------------------------------
# objective= 134.41982 , change in objective= 3.1193695
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.79143107 1.9514582  2.9949362 ]
# Var of the parameter distributions: sigma^2 = [0.4543721  0.16732538 0.19487843]
# Std deviation of the parameter distributions: sigma = [0.6740713  0.40905425 0.4414504 ]
# phi = [[ 0.79143107 -0.7888388 ]
#  [ 1.9514582  -1.787815  ]
#  [ 2.9949362  -1.6353793 ]]
# loss= 131.51999
# ---------------------------------
# objective= 131.51999 , change in objective= 2.899826
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.80218166 1.9528402  2.995344  ]
# Var of the parameter distributions: sigma^2 = [0.44438693 0.16186275 0.1887032 ]
# Std deviation of the parameter distributions: sigma = [0.66662353 0.4023217  0.4343998 ]
# phi = [[ 0.80218166 -0.81105965]
#  [ 1.9528402  -1.8210065 ]
#  [ 2.995344   -1.6675799 ]]
# loss= 128.81628
# ---------------------------------
# objective= 128.81628 , change in objective= 2.7037048
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.8119153 1.9540912 2.9957004]
# Var of the parameter distributions: sigma^2 = [0.43483824 0.15675077 0.1829131 ]
# Std deviation of the parameter distributions: sigma = [0.65942264 0.39591765 0.4276834 ]
# phi = [[ 0.8119153 -0.8327812]
#  [ 1.9540912 -1.8530982]
#  [ 2.9957004 -1.6987442]]
# loss= 126.2885
# ---------------------------------
# objective= 126.2885 , change in objective= 2.5277863
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.82072806 1.9552237  2.9960148 ]
# Var of the parameter distributions: sigma^2 = [0.42569792 0.15195659 0.17747298]
# Std deviation of the parameter distributions: sigma = [0.65245533 0.3898161  0.42127544]
# phi = [[ 0.82072806 -0.8540253 ]
#  [ 1.9552237  -1.8841604 ]
#  [ 2.9960148  -1.7289369 ]]
# loss= 123.919235
# ---------------------------------
# objective= 123.919235 , change in objective= 2.3692627
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.828707  1.956249  2.9962938]
# Var of the parameter distributions: sigma^2 = [0.41694027 0.14745128 0.17235193]
# Std deviation of the parameter distributions: sigma = [0.64570916 0.38399386 0.41515288]
# phi = [[ 0.828707  -0.8748123]
#  [ 1.956249  -1.9142574]
#  [ 2.9962938 -1.7582169]]
# loss= 121.69321
# ---------------------------------
# objective= 121.69321 , change in objective= 2.2260284
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.83593094 1.9571774  2.9965427 ]
# Var of the parameter distributions: sigma^2 = [0.40854165 0.14320943 0.16752253]
# Std deviation of the parameter distributions: sigma = [0.6391726  0.37843022 0.40929517]
# phi = [[ 0.83593094 -0.8951614 ]
#  [ 1.9571774  -1.9434472 ]
#  [ 2.9965427  -1.7866374 ]]
# loss= 119.59711
# ---------------------------------
# objective= 119.59711 , change in objective= 2.0960999
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.84247136 1.958018   2.9967656 ]
# Var of the parameter distributions: sigma^2 = [0.4004804  0.13920844 0.16296047]
# Std deviation of the parameter distributions: sigma = [0.6328352  0.37310648 0.40368363]
# phi = [[ 0.84247136 -0.9150905 ]
#  [ 1.958018   -1.9717829 ]
#  [ 2.9967656  -1.8142476 ]]
# loss= 117.61936
# ---------------------------------
# objective= 117.61936 , change in objective= 1.977745
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.84839284 1.958779   2.996966  ]
# Var of the parameter distributions: sigma^2 = [0.39273643 0.1354283  0.15864404]
# Std deviation of the parameter distributions: sigma = [0.6266869  0.3680058  0.39830142]
# phi = [[ 0.84839284 -0.9346165 ]
#  [ 1.958779   -1.999313  ]
#  [ 2.996966   -1.8410923 ]]
# loss= 115.74963
# ---------------------------------
# objective= 115.74963 , change in objective= 1.8697281
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.853754  1.9594679 2.997146 ]
# Var of the parameter distributions: sigma^2 = [0.3852914  0.13185109 0.15455385]
# Std deviation of the parameter distributions: sigma = [0.6207185  0.36311305 0.39313334]
# phi = [[ 0.853754  -0.9537553]
#  [ 1.9594679 -2.026082 ]
#  [ 2.997146  -1.8672128]]
# loss= 113.97889
# ---------------------------------
# objective= 113.97889 , change in objective= 1.7707443
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.85860777 1.9600917  2.9973083 ]
# Var of the parameter distributions: sigma^2 = [0.37812826 0.1284609  0.15067248]
# Std deviation of the parameter distributions: sigma = [0.61492133 0.3584144  0.38816553]
# phi = [[ 0.85860777 -0.97252184]
#  [ 1.9600917  -2.0521307 ]
#  [ 2.9973083  -1.8926468 ]]
# loss= 112.29907
# ---------------------------------
# objective= 112.29907 , change in objective= 1.6798172
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.86300224 1.9606565  2.997455  ]
# Var of the parameter distributions: sigma^2 = [0.37123123 0.12524334 0.1469843 ]
# Std deviation of the parameter distributions: sigma = [0.6092875  0.35389733 0.3833853 ]
# phi = [[ 0.86300224 -0.99093014]
#  [ 1.9606565  -2.0774968 ]
#  [ 2.997455   -1.9174296 ]]
# loss= 110.70299
# ---------------------------------
# objective= 110.70299 , change in objective= 1.5960846
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.86698085 1.9611678  2.9975872 ]
# Var of the parameter distributions: sigma^2 = [0.36458576 0.12218551 0.14347516]
# Std deviation of the parameter distributions: sigma = [0.60380936 0.34955043 0.37878114]
# phi = [[ 0.86698085 -1.0089935 ]
#  [ 1.9611678  -2.1022148 ]
#  [ 2.9975872  -1.9415934 ]]
# loss= 109.18428
# ---------------------------------
# objective= 109.18428 , change in objective= 1.5187073
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.87058294 1.9616308  2.9977067 ]
# Var of the parameter distributions: sigma^2 = [0.35817823 0.11927575 0.14013228]
# Std deviation of the parameter distributions: sigma = [0.5984799  0.3453632  0.37434244]
# phi = [[ 0.87058294 -1.0267246 ]
#  [ 1.9616308  -2.1263173 ]
#  [ 2.9977067  -1.9651685 ]]
# loss= 107.73717
# ---------------------------------
# objective= 107.73717 , change in objective= 1.447113
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.87384415 1.96205    2.997815  ]
# Var of the parameter distributions: sigma^2 = [0.35199606 0.11650351 0.13694407]
# Std deviation of the parameter distributions: sigma = [0.59329253 0.3413261  0.37005955]
# phi = [[ 0.87384415 -1.0441353 ]
#  [ 1.96205    -2.149834  ]
#  [ 2.997815   -1.9881827 ]]
# loss= 106.356514
# ---------------------------------
# objective= 106.356514 , change in objective= 1.3806534
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.8767967 1.9624294 2.9979126]
# Var of the parameter distributions: sigma^2 = [0.34602755 0.11385925 0.13390003]
# Std deviation of the parameter distributions: sigma = [0.5882411  0.33743036 0.36592352]
# phi = [[ 0.8767967 -1.0612369]
#  [ 1.9624294 -2.1727922]
#  [ 2.9979126 -2.0106618]]
# loss= 105.03765
# ---------------------------------
# objective= 105.03765 , change in objective= 1.3188629
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.8794699 1.962773  2.998001 ]
# Var of the parameter distributions: sigma^2 = [0.3402618  0.11133428 0.13099054]
# Std deviation of the parameter distributions: sigma = [0.5833196  0.33366793 0.36192614]
# phi = [[ 0.8794699 -1.07804  ]
#  [ 1.962773  -2.195218 ]
#  [ 2.998001  -2.0326302]]
# loss= 103.77639
# ---------------------------------
# objective= 103.77639 , change in objective= 1.261261
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.88189006 1.9630841  2.9980812 ]
# Var of the parameter distributions: sigma^2 = [0.33468857 0.10892065 0.12820685]
# Std deviation of the parameter distributions: sigma = [0.57852274 0.33003128 0.35805982]
# phi = [[ 0.88189006 -1.0945548 ]
#  [ 1.9630841  -2.2171357 ]
#  [ 2.9980812  -2.0541103 ]]
# loss= 102.56888
# ---------------------------------
# objective= 102.56888 , change in objective= 1.2075119
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.8840812 1.9633657 2.9981537]
# Var of the parameter distributions: sigma^2 = [0.32929844 0.10661115 0.12554094]
# Std deviation of the parameter distributions: sigma = [0.5738453  0.32651365 0.35431758]
# phi = [[ 0.8840812 -1.1107908]
#  [ 1.9633657 -2.238567 ]
#  [ 2.9981537 -2.0751233]]
# loss= 101.41167
# ---------------------------------
# objective= 101.41167 , change in objective= 1.1572113
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.88606495 1.9636207  2.9982193 ]
# Var of the parameter distributions: sigma^2 = [0.32408243 0.10439916 0.12298547]
# Std deviation of the parameter distributions: sigma = [0.5692824  0.32310858 0.35069284]
# phi = [[ 0.88606495 -1.1267574 ]
#  [ 1.9636207  -2.2595336 ]
#  [ 2.9982193  -2.095689  ]]
# loss= 100.30158
# ---------------------------------
# objective= 100.30158 , change in objective= 1.1100845
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.887861  1.9638516 2.9982786]
# Var of the parameter distributions: sigma^2 = [0.31903225 0.10227861 0.1205337 ]
# Std deviation of the parameter distributions: sigma = [0.5648294  0.31981027 0.34717965]
# phi = [[ 0.887861  -1.1424631]
#  [ 1.9638516 -2.2800548]
#  [ 2.9982786 -2.115826 ]]
# loss= 99.235725
# ---------------------------------
# objective= 99.235725 , change in objective= 1.0658569
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.8894871 1.9640605 2.9983323]
# Var of the parameter distributions: sigma^2 = [0.31414008 0.10024391 0.1181794 ]
# Std deviation of the parameter distributions: sigma = [0.560482   0.3166132  0.34377232]
# phi = [[ 0.8894871 -1.1579163]
#  [ 1.9640605 -2.300149 ]
#  [ 2.9983323 -2.1355515]]
# loss= 98.21143
# ---------------------------------
# objective= 98.21143 , change in objective= 1.024292
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89095926 1.9642497  2.998381  ]
# Var of the parameter distributions: sigma^2 = [0.3093986  0.09828995 0.11591687]
# Std deviation of the parameter distributions: sigma = [0.5562361  0.31351227 0.34046566]
# phi = [[ 0.89095926 -1.1731249 ]
#  [ 1.9642497  -2.3198335 ]
#  [ 2.998381   -2.154882  ]]
# loss= 97.226234
# ---------------------------------
# objective= 97.226234 , change in objective= 0.985199
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89229214 1.964421   2.998425  ]
# Var of the parameter distributions: sigma^2 = [0.30480093 0.09641202 0.11374085]
# Std deviation of the parameter distributions: sigma = [0.5520878  0.31050283 0.33725488]
# phi = [[ 0.89229214 -1.1880964 ]
#  [ 1.964421   -2.3391244 ]
#  [ 2.998425   -2.1738327 ]]
# loss= 96.277954
# ---------------------------------
# objective= 96.277954 , change in objective= 0.94828033
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89349884 1.9645761  2.9984648 ]
# Var of the parameter distributions: sigma^2 = [0.30034065 0.09460573 0.11164642]
# Std deviation of the parameter distributions: sigma = [0.5480334  0.30758044 0.33413535]
# phi = [[ 0.89349884 -1.202838  ]
#  [ 1.9645761  -2.3580372 ]
#  [ 2.9984648  -2.1924183 ]]
# loss= 95.36448
# ---------------------------------
# objective= 95.36448 , change in objective= 0.91347504
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.8945914 1.9647166 2.998501 ]
# Var of the parameter distributions: sigma^2 = [0.29601166 0.09286705 0.10962908]
# Std deviation of the parameter distributions: sigma = [0.5440695  0.30474094 0.33110282]
# phi = [[ 0.8945914 -1.2173564]
#  [ 1.9647166 -2.3765864]
#  [ 2.998501  -2.2106526]]
# loss= 94.483894
# ---------------------------------
# objective= 94.483894 , change in objective= 0.8805847
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89558053 1.9648436  2.9985337 ]
# Var of the parameter distributions: sigma^2 = [0.29180822 0.09119225 0.10768464]
# Std deviation of the parameter distributions: sigma = [0.5401928  0.30198056 0.32815337]
# phi = [[ 0.89558053 -1.2316585 ]
#  [ 1.9648436  -2.3947854 ]
#  [ 2.9985337  -2.2285483 ]]
# loss= 93.63445
# ---------------------------------
# objective= 93.63445 , change in objective= 0.8494415
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89647603 1.9649588  2.9985633 ]
# Var of the parameter distributions: sigma^2 = [0.28772494 0.08957785 0.1058092 ]
# Std deviation of the parameter distributions: sigma = [0.53639996 0.29929557 0.32528326]
# phi = [[ 0.89647603 -1.2457503 ]
#  [ 1.9649588  -2.4126472 ]
#  [ 2.9985633  -2.2461178 ]]
# loss= 92.81449
# ---------------------------------
# objective= 92.81449 , change in objective= 0.81996155
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89728683 1.965063   2.99859   ]
# Var of the parameter distributions: sigma^2 = [0.28375673 0.08802062 0.10399914]
# Std deviation of the parameter distributions: sigma = [0.5326882  0.29668272 0.32248896]
# phi = [[ 0.89728683 -1.259638  ]
#  [ 1.965063   -2.4301841 ]
#  [ 2.99859    -2.2633727 ]]
# loss= 92.02247
# ---------------------------------
# objective= 92.02247 , change in objective= 0.7920227
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89802086 1.9651574  2.9986143 ]
# Var of the parameter distributions: sigma^2 = [0.2798988  0.08651762 0.1022511 ]
# Std deviation of the parameter distributions: sigma = [0.52905464 0.29413876 0.31976727]
# phi = [[ 0.89802086 -1.2733272 ]
#  [ 1.9651574  -2.4474072 ]
#  [ 2.9986143  -2.2803237 ]]
# loss= 91.25702
# ---------------------------------
# objective= 91.25702 , change in objective= 0.7654495
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89868546 1.9652427  2.9986362 ]
# Var of the parameter distributions: sigma^2 = [0.27614656 0.08506601 0.10056195]
# Std deviation of the parameter distributions: sigma = [0.5254965  0.2916608  0.31711504]
# phi = [[ 0.89868546 -1.2868235 ]
#  [ 1.9652427  -2.4643278 ]
#  [ 2.9986362  -2.2969813 ]]
# loss= 90.51677
# ---------------------------------
# objective= 90.51677 , change in objective= 0.74024963
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.89928716 1.9653201  2.998656  ]
# Var of the parameter distributions: sigma^2 = [0.27249575 0.0836632  0.09892872]
# Std deviation of the parameter distributions: sigma = [0.5220113  0.2892459  0.31452936]
# phi = [[ 0.89928716 -1.3001323 ]
#  [ 1.9653201  -2.480956  ]
#  [ 2.998656   -2.3133557 ]]
# loss= 89.80051
# ---------------------------------
# objective= 89.80051 , change in objective= 0.7162628
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.8998319 1.9653901 2.9986742]
# Var of the parameter distributions: sigma^2 = [0.2689423  0.08230678 0.0973487 ]
# Std deviation of the parameter distributions: sigma = [0.5185965  0.28689158 0.31200755]
# phi = [[ 0.8998319 -1.3132584]
#  [ 1.9653901 -2.4973018]
#  [ 2.9986742 -2.3294559]]
# loss= 89.10705
# ---------------------------------
# objective= 89.10705 , change in objective= 0.69345856
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90032506 1.9654535  2.9986904 ]
# Var of the parameter distributions: sigma^2 = [0.26548234 0.08099446 0.09581932]
# Std deviation of the parameter distributions: sigma = [0.5152498  0.28459525 0.30954698]
# phi = [[ 0.90032506 -1.3262069 ]
#  [ 1.9654535  -2.5133746 ]
#  [ 2.9986904  -2.345291  ]]
# loss= 88.435394
# ---------------------------------
# objective= 88.435394 , change in objective= 0.67165375
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90077156 1.965511   2.9987051 ]
# Var of the parameter distributions: sigma^2 = [0.26211226 0.07972412 0.09433817]
# Std deviation of the parameter distributions: sigma = [0.51196903 0.2823546  0.30714518]
# phi = [[ 0.90077156 -1.3389823 ]
#  [ 1.965511   -2.5291831 ]
#  [ 2.9987051  -2.3608694 ]]
# loss= 87.78442
# ---------------------------------
# objective= 87.78442 , change in objective= 0.6509781
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9011758 1.9655629 2.9987185]
# Var of the parameter distributions: sigma^2 = [0.25882858 0.07849377 0.09290301]
# Std deviation of the parameter distributions: sigma = [0.508752   0.2801674  0.30479994]
# phi = [[ 0.9011758 -1.3515893]
#  [ 1.9655629 -2.544736 ]
#  [ 2.9987185 -2.3761992]]
# loss= 87.15324
# ---------------------------------
# objective= 87.15324 , change in objective= 0.6311798
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9015418 1.9656099 2.9987307]
# Var of the parameter distributions: sigma^2 = [0.255628   0.07730158 0.09151171]
# Std deviation of the parameter distributions: sigma = [0.5055967  0.27803162 0.30250904]
# phi = [[ 0.9015418 -1.364032 ]
#  [ 1.9656099 -2.560041 ]
#  [ 2.9987307 -2.3912883]]
# loss= 86.54097
# ---------------------------------
# objective= 86.54097 , change in objective= 0.61226654
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90187323 1.9656525  2.9987416 ]
# Var of the parameter distributions: sigma^2 = [0.2525074  0.07614576 0.0901623 ]
# Std deviation of the parameter distributions: sigma = [0.50250113 0.27594522 0.30027038]
# phi = [[ 0.90187323 -1.3763148 ]
#  [ 1.9656525  -2.575106  ]
#  [ 2.9987416  -2.406144  ]]
# loss= 85.94676
# ---------------------------------
# objective= 85.94676 , change in objective= 0.59420776
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9021732 1.9656911 2.9987514]
# Var of the parameter distributions: sigma^2 = [0.24946381 0.07502468 0.0888529 ]
# Std deviation of the parameter distributions: sigma = [0.49946353 0.27390632 0.29808205]
# phi = [[ 0.9021732 -1.3884414]
#  [ 1.9656911 -2.5899382]
#  [ 2.9987514 -2.420773 ]]
# loss= 85.36986
# ---------------------------------
# objective= 85.36986 , change in objective= 0.5769043
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90244484 1.965726   2.9987605 ]
# Var of the parameter distributions: sigma^2 = [0.24649443 0.0739368  0.08758175]
# Std deviation of the parameter distributions: sigma = [0.49648204 0.27191323 0.29594216]
# phi = [[ 0.90244484 -1.4004159 ]
#  [ 1.965726   -2.6045446 ]
#  [ 2.9987605  -2.4351826 ]]
# loss= 84.80942
# ---------------------------------
# objective= 84.80942 , change in objective= 0.56044006
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90269077 1.9657576  2.9987686 ]
# Var of the parameter distributions: sigma^2 = [0.24359657 0.07288066 0.08634721]
# Std deviation of the parameter distributions: sigma = [0.49355504 0.2699642  0.29384896]
# phi = [[ 0.90269077 -1.4122418 ]
#  [ 1.9657576  -2.618932  ]
#  [ 2.9987686  -2.4493787 ]]
# loss= 84.26487
# ---------------------------------
# objective= 84.26487 , change in objective= 0.54454803
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9029134 1.9657862 2.998776 ]
# Var of the parameter distributions: sigma^2 = [0.24076766 0.07185488 0.08514772]
# Std deviation of the parameter distributions: sigma = [0.4906808  0.2680576  0.29180083]
# phi = [[ 0.9029134 -1.4239229]
#  [ 1.9657862 -2.6331067]
#  [ 2.998776  -2.4633677]]
# loss= 83.73545
# ---------------------------------
# objective= 83.73545 , change in objective= 0.52941895
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.903115  1.9658121 2.9987826]
# Var of the parameter distributions: sigma^2 = [0.23800527 0.07085817 0.08398177]
# Std deviation of the parameter distributions: sigma = [0.48785785 0.266192   0.28979608]
# phi = [[ 0.903115  -1.4354625]
#  [ 1.9658121 -2.647075 ]
#  [ 2.9987826 -2.4771554]]
# loss= 83.2206
# ---------------------------------
# objective= 83.2206 , change in objective= 0.51485443
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9032975 1.9658356 2.9987886]
# Var of the parameter distributions: sigma^2 = [0.23530708 0.06988932 0.08284802]
# Std deviation of the parameter distributions: sigma = [0.48508462 0.26436588 0.28783333]
# phi = [[ 0.9032975 -1.4468639]
#  [ 1.9658356 -2.6608424]
#  [ 2.9987886 -2.4907475]]
# loss= 82.71969
# ---------------------------------
# objective= 82.71969 , change in objective= 0.5009079
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9034627 1.9658568 2.998794 ]
# Var of the parameter distributions: sigma^2 = [0.23267084 0.06894716 0.08174512]
# Std deviation of the parameter distributions: sigma = [0.48235968 0.26257792 0.28591102]
# phi = [[ 0.9034627 -1.4581305]
#  [ 1.9658568 -2.6744149]
#  [ 2.998794  -2.5041492]]
# loss= 82.232185
# ---------------------------------
# objective= 82.232185 , change in objective= 0.48750305
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9036123 1.965876  2.998799 ]
# Var of the parameter distributions: sigma^2 = [0.23009449 0.06803061 0.08067182]
# Std deviation of the parameter distributions: sigma = [0.47968167 0.26082677 0.28402784]
# phi = [[ 0.9036123 -1.4692652]
#  [ 1.965876  -2.6877975]
#  [ 2.998799  -2.517366 ]]
# loss= 81.75756
# ---------------------------------
# objective= 81.75756 , change in objective= 0.47462463
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90374774 1.9658934  2.9988036 ]
# Var of the parameter distributions: sigma^2 = [0.22757599 0.06713863 0.07962695]
# Std deviation of the parameter distributions: sigma = [0.47704923 0.25911123 0.28218248]
# phi = [[ 0.90374774 -1.4802711 ]
#  [ 1.9658934  -2.7009957 ]
#  [ 2.9988036  -2.5304027 ]]
# loss= 81.29528
# ---------------------------------
# objective= 81.29528 , change in objective= 0.46228027
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90387034 1.9659091  2.9988077 ]
# Var of the parameter distributions: sigma^2 = [0.22511338 0.06627025 0.07860941]
# Std deviation of the parameter distributions: sigma = [0.47446114 0.25743008 0.2803737 ]
# phi = [[ 0.90387034 -1.4911511 ]
#  [ 1.9659091  -2.7140143 ]
#  [ 2.9988077  -2.543264  ]]
# loss= 80.84492
# ---------------------------------
# objective= 80.84492 , change in objective= 0.45036316
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9039813 1.9659234 2.9988112]
# Var of the parameter distributions: sigma^2 = [0.22270484 0.06542452 0.07761811]
# Std deviation of the parameter distributions: sigma = [0.47191614 0.2557822  0.27860028]
# phi = [[ 0.9039813 -1.501908 ]
#  [ 1.9659234 -2.7268581]
#  [ 2.9988112 -2.5559545]]
# loss= 80.40599
# ---------------------------------
# objective= 80.40599 , change in objective= 0.4389267
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9040818 1.9659364 2.9988146]
# Var of the parameter distributions: sigma^2 = [0.22034864 0.0646006  0.07665206]
# Std deviation of the parameter distributions: sigma = [0.46941307 0.25416648 0.27686107]
# phi = [[ 0.9040818 -1.5125443]
#  [ 1.9659364 -2.7395315]
#  [ 2.9988146 -2.5684788]]
# loss= 79.978065
# ---------------------------------
# objective= 79.978065 , change in objective= 0.4279251
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90417284 1.9659481  2.9988177 ]
# Var of the parameter distributions: sigma^2 = [0.21804303 0.06379765 0.0757103 ]
# Std deviation of the parameter distributions: sigma = [0.46695077 0.25258195 0.27515504]
# phi = [[ 0.90417284 -1.5230628 ]
#  [ 1.9659481  -2.752039  ]
#  [ 2.9988177  -2.580841  ]]
# loss= 79.56075
# ---------------------------------
# objective= 79.56075 , change in objective= 0.41731262
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9042552 1.9659587 2.9988203]
# Var of the parameter distributions: sigma^2 = [0.21578643 0.06301486 0.07479193]
# Std deviation of the parameter distributions: sigma = [0.46452817 0.2510276  0.27348113]
# phi = [[ 0.9042552 -1.5334661]
#  [ 1.9659587 -2.7643847]
#  [ 2.9988203 -2.5930452]]
# loss= 79.15366
# ---------------------------------
# objective= 79.15366 , change in objective= 0.40708923
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9043298 1.9659683 2.9988227]
# Var of the parameter distributions: sigma^2 = [0.2135773  0.06225148 0.07389609]
# Std deviation of the parameter distributions: sigma = [0.46214423 0.24950247 0.27183834]
# phi = [[ 0.9043298 -1.5437565]
#  [ 1.9659683 -2.776573 ]
#  [ 2.9988227 -2.6050954]]
# loss= 78.756424
# ---------------------------------
# objective= 78.756424 , change in objective= 0.39723969
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9043973 1.965977  2.9988248]
# Var of the parameter distributions: sigma^2 = [0.21141413 0.0615068  0.07302196]
# Std deviation of the parameter distributions: sigma = [0.45979792 0.24800564 0.27022576]
# phi = [[ 0.9043973 -1.5539364]
#  [ 1.965977  -2.7886076]
#  [ 2.9988248 -2.616995 ]]
# loss= 78.36868
# ---------------------------------
# objective= 78.36868 , change in objective= 0.3877411
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90445846 1.9659848  2.998827  ]
# Var of the parameter distributions: sigma^2 = [0.20929551 0.06078013 0.07216875]
# Std deviation of the parameter distributions: sigma = [0.45748827 0.24653627 0.26864243]
# phi = [[ 0.90445846 -1.5640081 ]
#  [ 1.9659848  -2.8004923 ]
#  [ 2.998827   -2.6287482 ]]
# loss= 77.9901
# ---------------------------------
# objective= 77.9901 , change in objective= 0.37858582
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90451384 1.965992   2.998829  ]
# Var of the parameter distributions: sigma^2 = [0.20722008 0.06007085 0.07133573]
# Std deviation of the parameter distributions: sigma = [0.45521432 0.24509355 0.2670875 ]
# phi = [[ 0.90451384 -1.5739739 ]
#  [ 1.965992   -2.8122306 ]
#  [ 2.998829   -2.640358  ]]
# loss= 77.62039
# ---------------------------------
# objective= 77.62039 , change in objective= 0.3697052
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90456396 1.9659984  2.9988306 ]
# Var of the parameter distributions: sigma^2 = [0.2051865  0.05937832 0.07052217]
# Std deviation of the parameter distributions: sigma = [0.45297515 0.24367668 0.26556012]
# phi = [[ 0.90456396 -1.583836  ]
#  [ 1.9659984  -2.823826  ]
#  [ 2.9988306  -2.651828  ]]
# loss= 77.25921
# ---------------------------------
# objective= 77.25921 , change in objective= 0.36118317
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9046093 1.9660043 2.998832 ]
# Var of the parameter distributions: sigma^2 = [0.20319355 0.05870197 0.06972741]
# Std deviation of the parameter distributions: sigma = [0.45076996 0.24228488 0.26405948]
# phi = [[ 0.9046093 -1.5935963]
#  [ 1.9660043 -2.835282 ]
#  [ 2.998832  -2.6631618]]
# loss= 76.90628
# ---------------------------------
# objective= 76.90628 , change in objective= 0.35292816
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9046504 1.9660095 2.9988334]
# Var of the parameter distributions: sigma^2 = [0.20124    0.05804121 0.06895081]
# Std deviation of the parameter distributions: sigma = [0.44859782 0.24091744 0.26258487]
# phi = [[ 0.9046504 -1.6032571]
#  [ 1.9660095 -2.846602 ]
#  [ 2.9988334 -2.674362 ]]
# loss= 76.5613
# ---------------------------------
# objective= 76.5613 , change in objective= 0.34497833
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9046876 1.9660143 2.9988346]
# Var of the parameter distributions: sigma^2 = [0.19932473 0.05739553 0.06819173]
# Std deviation of the parameter distributions: sigma = [0.44645798 0.23957364 0.26113546]
# phi = [[ 0.9046876 -1.61282  ]
#  [ 1.9660143 -2.8577888]
#  [ 2.9988346 -2.685432 ]]
# loss= 76.224045
# ---------------------------------
# objective= 76.224045 , change in objective= 0.3372574
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90472126 1.9660186  2.9988358 ]
# Var of the parameter distributions: sigma^2 = [0.19744657 0.05676442 0.06744961]
# Std deviation of the parameter distributions: sigma = [0.4443496  0.23825286 0.25971064]
# phi = [[ 0.90472126 -1.6222873 ]
#  [ 1.9660186  -2.8688455 ]
#  [ 2.9988358  -2.6963744 ]]
# loss= 75.89427
# ---------------------------------
# objective= 75.89427 , change in objective= 0.32977295
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9047517 1.9660225 2.9988368]
# Var of the parameter distributions: sigma^2 = [0.19560449 0.05614739 0.06672388]
# Std deviation of the parameter distributions: sigma = [0.44227195 0.2369544  0.25830966]
# phi = [[ 0.9047517 -1.6316606]
#  [ 1.9660225 -2.879775 ]
#  [ 2.9988368 -2.7071924]]
# loss= 75.5717
# ---------------------------------
# objective= 75.5717 , change in objective= 0.3225708
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9047793 1.9660261 2.9988377]
# Var of the parameter distributions: sigma^2 = [0.19379745 0.05554397 0.06601399]
# Std deviation of the parameter distributions: sigma = [0.44022432 0.23567767 0.25693187]
# phi = [[ 0.9047793 -1.6409417]
#  [ 1.9660261 -2.8905804]
#  [ 2.9988377 -2.7178886]]
# loss= 75.25612
# ---------------------------------
# objective= 75.25612 , change in objective= 0.31558228
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9048043 1.9660293 2.9988384]
# Var of the parameter distributions: sigma^2 = [0.19202445 0.05495369 0.06531943]
# Std deviation of the parameter distributions: sigma = [0.43820596 0.23442203 0.25557664]
# phi = [[ 0.9048043 -1.6501325]
#  [ 1.9660293 -2.9012644]
#  [ 2.9988384 -2.7284658]]
# loss= 74.94729
# ---------------------------------
# objective= 74.94729 , change in objective= 0.30883026
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90482694 1.9660321  2.9988391 ]
# Var of the parameter distributions: sigma^2 = [0.19028454 0.05437616 0.0646397 ]
# Std deviation of the parameter distributions: sigma = [0.43621618 0.23318696 0.2542434 ]
# phi = [[ 0.90482694 -1.6592348 ]
#  [ 1.9660321  -2.9118295 ]
#  [ 2.9988391  -2.7389264 ]]
# loss= 74.645
# ---------------------------------
# objective= 74.645 , change in objective= 0.30229187
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90484744 1.9660348  2.9988399 ]
# Var of the parameter distributions: sigma^2 = [0.18857679 0.05381094 0.06397437]
# Std deviation of the parameter distributions: sigma = [0.4342543  0.23197186 0.25293154]
# phi = [[ 0.90484744 -1.66825   ]
#  [ 1.9660348  -2.9222784 ]
#  [ 2.9988399  -2.7492728 ]]
# loss= 74.34904
# ---------------------------------
# objective= 74.34904 , change in objective= 0.29595947
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.904866  1.9660372 2.9988406]
# Var of the parameter distributions: sigma^2 = [0.18690035 0.05325767 0.06332294]
# Std deviation of the parameter distributions: sigma = [0.43231973 0.23077624 0.2516405 ]
# phi = [[ 0.904866  -1.6771797]
#  [ 1.9660372 -2.9326134]
#  [ 2.9988406 -2.7595077]]
# loss= 74.05926
# ---------------------------------
# objective= 74.05926 , change in objective= 0.28977966
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9048828 1.9660393 2.998841 ]
# Var of the parameter distributions: sigma^2 = [0.18525434 0.05271596 0.06268499]
# Std deviation of the parameter distributions: sigma = [0.43041182 0.22959957 0.2503697 ]
# phi = [[ 0.9048828 -1.6860256]
#  [ 1.9660393 -2.942837 ]
#  [ 2.998841  -2.7696333]]
# loss= 73.775406
# ---------------------------------
# objective= 73.775406 , change in objective= 0.28385162
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.904898  1.9660413 2.9988415]
# Var of the parameter distributions: sigma^2 = [0.18363792 0.05218546 0.06206011]
# Std deviation of the parameter distributions: sigma = [0.42852995 0.22844136 0.24911866]
# phi = [[ 0.904898  -1.6947893]
#  [ 1.9660413 -2.9529514]
#  [ 2.9988415 -2.7796519]]
# loss= 73.497375
# ---------------------------------
# objective= 73.497375 , change in objective= 0.2780304
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.90491176 1.9660431  2.998842  ]
# Var of the parameter distributions: sigma^2 = [0.18205032 0.05166581 0.0614479 ]
# Std deviation of the parameter distributions: sigma = [0.42667356 0.22730114 0.24788688]
# phi = [[ 0.90491176 -1.7034721 ]
#  [ 1.9660431  -2.962959  ]
#  [ 2.998842   -2.7895656 ]]
# loss= 73.22492
# ---------------------------------
# objective= 73.22492 , change in objective= 0.2724533
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9049242 1.9660447 2.9988425]
# Var of the parameter distributions: sigma^2 = [0.18049078 0.05115668 0.06084799]
# Std deviation of the parameter distributions: sigma = [0.42484206 0.22617842 0.24667385]
# phi = [[ 0.9049242 -1.7120756]
#  [ 1.9660447 -2.9728622]
#  [ 2.9988425 -2.7993765]]
# loss= 72.95792
# ---------------------------------
# objective= 72.95792 , change in objective= 0.26700592
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9049355 1.9660461 2.9988427]
# Var of the parameter distributions: sigma^2 = [0.17895855 0.05065776 0.06026   ]
# Std deviation of the parameter distributions: sigma = [0.4230349  0.22507279 0.24547912]
# phi = [[ 0.9049355 -1.7206011]
#  [ 1.9660461 -2.982663 ]
#  [ 2.9988427 -2.8090868]]
# loss= 72.69619
# ---------------------------------
# objective= 72.69619 , change in objective= 0.26172638
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9049457 1.9660474 2.998843 ]
# Var of the parameter distributions: sigma^2 = [0.17745292 0.05016875 0.05968358]
# Std deviation of the parameter distributions: sigma = [0.42125162 0.22398381 0.24430223]
# phi = [[ 0.9049457 -1.7290499]
#  [ 1.9660474 -2.992363 ]
#  [ 2.998843  -2.8186984]]
# loss= 72.4396
# ---------------------------------
# objective= 72.4396 , change in objective= 0.2565918
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.9049549 1.9660486 2.9988432]
# ...
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04831653 0.01234124 0.01478266]
# Std deviation of the parameter distributions: sigma = [0.2198102  0.11109114 0.12158395]
# phi = [[ 0.905043  -3.0299816]
#  [ 1.9660598 -4.394809 ]
#  [ 2.998846  -4.2143006]]
# loss= 52.880573
# ---------------------------------
# objective= 52.880573 , change in objective= 0.011581421
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04822403 0.01231677 0.01475341]
# Std deviation of the parameter distributions: sigma = [0.21959971 0.11098093 0.12146362]
# phi = [[ 0.905043  -3.0318978]
#  [ 1.9660598 -4.396794 ]
#  [ 2.998846  -4.216281 ]]
# loss= 52.869057
# ---------------------------------
# objective= 52.869057 , change in objective= 0.011516571
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04813195 0.01229241 0.01472429]
# Std deviation of the parameter distributions: sigma = [0.21938995 0.11087112 0.1213437 ]
# phi = [[ 0.905043  -3.0338092]
#  [ 1.9660598 -4.3987737]
#  [ 2.998846  -4.2182565]]
# loss= 52.857594
# ---------------------------------
# objective= 52.857594 , change in objective= 0.011463165
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04804025 0.01226815 0.0146953 ]
# Std deviation of the parameter distributions: sigma = [0.21918087 0.11076169 0.12122419]
# phi = [[ 0.905043  -3.035716 ]
#  [ 1.9660598 -4.4007487]
#  [ 2.998846  -4.2202272]]
# loss= 52.846188
# ---------------------------------
# objective= 52.846188 , change in objective= 0.011405945
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04794895 0.012244   0.01466644]
# Std deviation of the parameter distributions: sigma = [0.21897249 0.11065263 0.12110509]
# phi = [[ 0.905043  -3.0376184]
#  [ 1.9660598 -4.402719 ]
#  [ 2.998846  -4.2221932]]
# loss= 52.834835
# ---------------------------------
# objective= 52.834835 , change in objective= 0.011352539
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04785805 0.01221996 0.01463771]
# Std deviation of the parameter distributions: sigma = [0.21876483 0.11054393 0.12098639]
# phi = [[ 0.905043  -3.039516 ]
#  [ 1.9660598 -4.4046845]
#  [ 2.998846  -4.2241545]]
# loss= 52.82354
# ---------------------------------
# objective= 52.82354 , change in objective= 0.011295319
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04776753 0.01219602 0.0146091 ]
# Std deviation of the parameter distributions: sigma = [0.21855786 0.11043561 0.12086812]
# phi = [[ 0.905043  -3.041409 ]
#  [ 1.9660598 -4.4066453]
#  [ 2.998846  -4.2261105]]
# loss= 52.812298
# ---------------------------------
# objective= 52.812298 , change in objective= 0.011241913
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04767741 0.0121722  0.01458063]
# Std deviation of the parameter distributions: sigma = [0.21835157 0.11032768 0.12075026]
# phi = [[ 0.905043  -3.0432975]
#  [ 1.9660598 -4.408601 ]
#  [ 2.998846  -4.2280617]]
# loss= 52.801113
# ---------------------------------
# objective= 52.801113 , change in objective= 0.011184692
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04758766 0.01214848 0.01455227]
# Std deviation of the parameter distributions: sigma = [0.21814597 0.11022013 0.1206328 ]
# phi = [[ 0.905043  -3.0451818]
#  [ 1.9660598 -4.4105515]
#  [ 2.998846  -4.230008 ]]
# loss= 52.78998
# ---------------------------------
# objective= 52.78998 , change in objective= 0.011131287
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.0474983  0.01212486 0.01452404]
# Std deviation of the parameter distributions: sigma = [0.21794105 0.11011294 0.12051574]
# phi = [[ 0.905043  -3.0470614]
#  [ 1.9660598 -4.4124975]
#  [ 2.998846  -4.23195  ]]
# loss= 52.778904
# ---------------------------------
# objective= 52.778904 , change in objective= 0.011077881
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04740931 0.01210134 0.01449594]
# Std deviation of the parameter distributions: sigma = [0.2177368  0.11000611 0.12039908]
# phi = [[ 0.905043  -3.0489366]
#  [ 1.9660598 -4.4144387]
#  [ 2.998846  -4.2338867]]
# loss= 52.76788
# ---------------------------------
# objective= 52.76788 , change in objective= 0.011024475
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04732071 0.01207793 0.01446795]
# Std deviation of the parameter distributions: sigma = [0.21753323 0.10989965 0.1202828 ]
# phi = [[ 0.905043  -3.0508072]
#  [ 1.9660598 -4.416375 ]
#  [ 2.998846  -4.2358193]]
# loss= 52.756912
# ---------------------------------
# objective= 52.756912 , change in objective= 0.010967255
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04723248 0.01205462 0.01444009]
# Std deviation of the parameter distributions: sigma = [0.21733034 0.10979354 0.12016691]
# phi = [[ 0.905043  -3.0526736]
#  [ 1.9660598 -4.4183073]
#  [ 2.998846  -4.237747 ]]
# loss= 52.745995
# ---------------------------------
# objective= 52.745995 , change in objective= 0.010917664
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04714462 0.01203141 0.01441234]
# Std deviation of the parameter distributions: sigma = [0.21712813 0.10968778 0.12005142]
# phi = [[ 0.905043  -3.0545354]
#  [ 1.9660598 -4.4202347]
#  [ 2.998846  -4.2396703]]
# loss= 52.735126
# ---------------------------------
# objective= 52.735126 , change in objective= 0.0108680725
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04705713 0.0120083  0.01438472]
# Std deviation of the parameter distributions: sigma = [0.21692654 0.10958239 0.11993632]
# phi = [[ 0.905043  -3.056393 ]
#  [ 1.9660598 -4.4221573]
#  [ 2.998846  -4.2415886]]
# loss= 52.72431
# ---------------------------------
# objective= 52.72431 , change in objective= 0.010814667
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04697001 0.01198529 0.01435722]
# Std deviation of the parameter distributions: sigma = [0.21672566 0.10947736 0.11982163]
# phi = [[ 0.905043  -3.058246 ]
#  [ 1.9660598 -4.424075 ]
#  [ 2.998846  -4.243502 ]]
# loss= 52.713547
# ---------------------------------
# objective= 52.713547 , change in objective= 0.010765076
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04688326 0.01196238 0.01432984]
# Std deviation of the parameter distributions: sigma = [0.21652544 0.10937269 0.1197073 ]
# phi = [[ 0.905043  -3.0600946]
#  [ 1.9660598 -4.425988 ]
#  [ 2.998846  -4.2454114]]
# loss= 52.702843
# ---------------------------------
# objective= 52.702843 , change in objective= 0.0107040405
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04679687 0.01193957 0.01430257]
# Std deviation of the parameter distributions: sigma = [0.21632583 0.10926835 0.11959336]
# phi = [[ 0.905043  -3.061939 ]
#  [ 1.9660598 -4.427897 ]
#  [ 2.998846  -4.247316 ]]
# loss= 52.69218
# ---------------------------------
# objective= 52.69218 , change in objective= 0.010662079
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04671083 0.01191686 0.01427542]
# Std deviation of the parameter distributions: sigma = [0.21612689 0.10916438 0.11947979]
# phi = [[ 0.905043  -3.063779 ]
#  [ 1.9660598 -4.429801 ]
#  [ 2.998846  -4.249216 ]]
# loss= 52.681572
# ---------------------------------
# objective= 52.681572 , change in objective= 0.010608673
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04662516 0.01189424 0.01424839]
# Std deviation of the parameter distributions: sigma = [0.2159286  0.10906073 0.11936661]
# phi = [[ 0.905043  -3.065615 ]
#  [ 1.9660598 -4.4317007]
#  [ 2.998846  -4.2511115]]
# loss= 52.671013
# ---------------------------------
# objective= 52.671013 , change in objective= 0.010559082
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04653984 0.01187173 0.01422147]
# Std deviation of the parameter distributions: sigma = [0.21573095 0.10895745 0.11925382]
# phi = [[ 0.905043  -3.0674465]
#  [ 1.9660598 -4.4335957]
#  [ 2.998846  -4.253002 ]]
# loss= 52.660503
# ---------------------------------
# objective= 52.660503 , change in objective= 0.010509491
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04645488 0.01184931 0.01419467]
# Std deviation of the parameter distributions: sigma = [0.21553394 0.10885452 0.1191414 ]
# phi = [[ 0.905043  -3.0692737]
#  [ 1.9660598 -4.435486 ]
#  [ 2.998846  -4.2548885]]
# loss= 52.650047
# ---------------------------------
# objective= 52.650047 , change in objective= 0.010456085
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04637028 0.01182698 0.01416798]
# Std deviation of the parameter distributions: sigma = [0.21533757 0.10875193 0.11902934]
# phi = [[ 0.905043  -3.0710967]
#  [ 1.9660598 -4.4373717]
#  [ 2.998846  -4.2567706]]
# loss= 52.63964
# ---------------------------------
# objective= 52.63964 , change in objective= 0.010406494
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04628602 0.01180475 0.01414141]
# Std deviation of the parameter distributions: sigma = [0.21514186 0.10864966 0.11891766]
# phi = [[ 0.905043  -3.0729153]
#  [ 1.9660598 -4.4392533]
#  [ 2.998846  -4.258648 ]]
# loss= 52.62928
# ---------------------------------
# objective= 52.62928 , change in objective= 0.010360718
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.0462021  0.01178261 0.01411495]
# Std deviation of the parameter distributions: sigma = [0.21494675 0.10854775 0.11880635]
# phi = [[ 0.905043  -3.07473  ]
#  [ 1.9660598 -4.44113  ]
#  [ 2.998846  -4.260521 ]]
# loss= 52.61897
# ---------------------------------
# objective= 52.61897 , change in objective= 0.010311127
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04611854 0.01176057 0.0140886 ]
# Std deviation of the parameter distributions: sigma = [0.21475229 0.10844617 0.11869542]
# phi = [[ 0.905043  -3.0765402]
#  [ 1.9660598 -4.4430027]
#  [ 2.998846  -4.262389 ]]
# loss= 52.608704
# ---------------------------------
# objective= 52.608704 , change in objective= 0.01026535
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04603531 0.01173862 0.01406237]
# Std deviation of the parameter distributions: sigma = [0.21455842 0.10834491 0.11858485]
# phi = [[ 0.905043  -3.0783465]
#  [ 1.9660598 -4.444871 ]
#  [ 2.998846  -4.264253 ]]
# loss= 52.59849
# ---------------------------------
# objective= 52.59849 , change in objective= 0.010211945
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04595243 0.01171677 0.01403624]
# Std deviation of the parameter distributions: sigma = [0.21436518 0.10824402 0.11847463]
# phi = [[ 0.905043  -3.0801485]
#  [ 1.9660598 -4.4467344]
#  [ 2.998846  -4.266113 ]]
# loss= 52.58832
# ---------------------------------
# objective= 52.58832 , change in objective= 0.010169983
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04586989 0.011695   0.01401022]
# Std deviation of the parameter distributions: sigma = [0.21417257 0.10814343 0.11836478]
# phi = [[ 0.905043  -3.0819464]
#  [ 1.9660598 -4.4485936]
#  [ 2.998846  -4.267968 ]]
# loss= 52.578205
# ---------------------------------
# objective= 52.578205 , change in objective= 0.010116577
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04578769 0.01167333 0.01398431]
# Std deviation of the parameter distributions: sigma = [0.21398059 0.10804319 0.11825527]
# phi = [[ 0.905043  -3.08374  ]
#  [ 1.9660598 -4.4504485]
#  [ 2.998846  -4.2698193]]
# loss= 52.568134
# ---------------------------------
# objective= 52.568134 , change in objective= 0.010070801
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04570583 0.01165175 0.01395851]
# Std deviation of the parameter distributions: sigma = [0.2137892  0.10794326 0.11814613]
# phi = [[ 0.905043  -3.0855296]
#  [ 1.9660598 -4.452299 ]
#  [ 2.998846  -4.271666 ]]
# loss= 52.558105
# ---------------------------------
# objective= 52.558105 , change in objective= 0.010028839
# --------
# -----------  AnalyticModel Summary---------------------
# Mean of the parameter distributions: mu = [0.905043  1.9660598 2.998846 ]
# Var of the parameter distributions: sigma^2 = [0.04562429 0.01163025 0.01393282]
# Std deviation of the parameter distributions: sigma = [0.21359843 0.10784366 0.11803737]
# phi = [[ 0.905043  -3.087315 ]
#  [ 1.9660598 -4.4541454]
#  [ 2.998846  -4.273508 ]]
# loss= 52.548126
# ---------------------------------
# objective= 52.548126 , change in objective= 0.009979248
# --------
# [[ 0.905043  -3.0890965]
#  [ 1.9660598 -4.4559875]
#  [ 2.998846  -4.275346 ]]
# [[ 0.90504336 -4.6052704 ]
#  [ 1.9660599  -5.998208  ]
#  [ 2.9988465  -5.8159175 ]]
# 49.389194

# %% [markdown]
# #### Stochastic gradient descent

# %%
#phi=np.array((1.,1.,1.,1.))

model_GD = VAE(X2, y)
#model_GD.form_derivs()


obj=1000
dobj=1000

gamma=0.001
phi=model_GD.phi
print('Phi0=', phi)

S=5000
while dobj >10e-4:
    key, *subkeys = random.split(key, 2)
    obj_new, gra = model.dloss(phi, S, subkeys[0])
    phinew = phi - gamma*  gra
    phi=phinew
    model_GD.encoder(phi)
    dobj = np.abs(obj-obj_new)
    obj=obj_new
    print('objective=',obj, ', change in objective=', dobj)
    print('--------')

phi_GD=phi
# Out:
# Phi0= [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# warning - encoder run - possibly bad idea
# objective= 2710.647 , change in objective= 1710.647
# --------
# warning - encoder run - possibly bad idea
# objective= 1329.4712 , change in objective= 1381.1758
# --------
# warning - encoder run - possibly bad idea
# objective= 771.4256 , change in objective= 558.0456
# --------
# warning - encoder run - possibly bad idea
# objective= 512.99927 , change in objective= 258.42633
# --------
# warning - encoder run - possibly bad idea
# objective= 383.8517 , change in objective= 129.14755
# --------
# warning - encoder run - possibly bad idea
# objective= 318.31693 , change in objective= 65.53479
# --------
# warning - encoder run - possibly bad idea
# objective= 285.83356 , change in objective= 32.483368
# --------
# warning - encoder run - possibly bad idea
# objective= 255.32863 , change in objective= 30.504929
# --------
# warning - encoder run - possibly bad idea
# objective= 235.8587 , change in objective= 19.469925
# --------
# warning - encoder run - possibly bad idea
# objective= 225.0909 , change in objective= 10.767807
# --------
# warning - encoder run - possibly bad idea
# objective= 209.7424 , change in objective= 15.3484955
# --------
# warning - encoder run - possibly bad idea
# objective= 200.49931 , change in objective= 9.243088
# --------
# warning - encoder run - possibly bad idea
# objective= 189.33284 , change in objective= 11.166473
# --------
# warning - encoder run - possibly bad idea
# objective= 182.99596 , change in objective= 6.3368835
# --------
# warning - encoder run - possibly bad idea
# objective= 174.38254 , change in objective= 8.613419
# --------
# warning - encoder run - possibly bad idea
# objective= 167.81683 , change in objective= 6.5657043
# --------
# warning - encoder run - possibly bad idea
# objective= 163.28654 , change in objective= 4.5302887
# --------
# warning - encoder run - possibly bad idea
# objective= 159.64046 , change in objective= 3.6460876
# --------
# warning - encoder run - possibly bad idea
# objective= 153.3837 , change in objective= 6.2567596
# --------
# warning - encoder run - possibly bad idea
# objective= 150.57411 , change in objective= 2.8095856
# --------
# warning - encoder run - possibly bad idea
# objective= 142.47049 , change in objective= 8.103622
# --------
# warning - encoder run - possibly bad idea
# objective= 140.3348 , change in objective= 2.1356964
# --------
# warning - encoder run - possibly bad idea
# objective= 136.99376 , change in objective= 3.341034
# --------
# warning - encoder run - possibly bad idea
# objective= 133.15204 , change in objective= 3.8417206
# --------
# warning - encoder run - possibly bad idea
# objective= 130.3333 , change in objective= 2.8187408
# --------
# warning - encoder run - possibly bad idea
# objective= 127.50724 , change in objective= 2.8260574
# --------
# warning - encoder run - possibly bad idea
# objective= 126.91708 , change in objective= 0.59015656
# --------
# warning - encoder run - possibly bad idea
# objective= 124.23128 , change in objective= 2.6858063
# --------
# warning - encoder run - possibly bad idea
# objective= 122.874695 , change in objective= 1.3565826
# --------
# warning - encoder run - possibly bad idea
# objective= 117.19408 , change in objective= 5.6806183
# --------
# warning - encoder run - possibly bad idea
# objective= 118.567856 , change in objective= 1.3737793
# --------
# warning - encoder run - possibly bad idea
# objective= 114.842354 , change in objective= 3.725502
# --------
# warning - encoder run - possibly bad idea
# objective= 114.478775 , change in objective= 0.3635788
# --------
# warning - encoder run - possibly bad idea
# objective= 112.69267 , change in objective= 1.7861023
# --------
# warning - encoder run - possibly bad idea
# objective= 111.228584 , change in objective= 1.4640884
# --------
# warning - encoder run - possibly bad idea
# objective= 108.11767 , change in objective= 3.1109161
# --------
# warning - encoder run - possibly bad idea
# objective= 106.986534 , change in objective= 1.131134
# --------
# warning - encoder run - possibly bad idea
# objective= 106.45002 , change in objective= 0.5365143
# --------
# warning - encoder run - possibly bad idea
# objective= 105.008125 , change in objective= 1.4418945
# --------
# warning - encoder run - possibly bad idea
# objective= 103.61103 , change in objective= 1.3970947
# --------
# warning - encoder run - possibly bad idea
# objective= 102.95954 , change in objective= 0.65148926
# --------
# warning - encoder run - possibly bad idea
# objective= 101.753204 , change in objective= 1.206337
# --------
# warning - encoder run - possibly bad idea
# objective= 100.181244 , change in objective= 1.5719604
# --------
# warning - encoder run - possibly bad idea
# objective= 100.67531 , change in objective= 0.49406433
# --------
# warning - encoder run - possibly bad idea
# objective= 97.37287 , change in objective= 3.3024368
# --------
# warning - encoder run - possibly bad idea
# objective= 97.783134 , change in objective= 0.41026306
# --------
# warning - encoder run - possibly bad idea
# objective= 95.00652 , change in objective= 2.7766113
# --------
# warning - encoder run - possibly bad idea
# objective= 96.19679 , change in objective= 1.1902695
# --------
# warning - encoder run - possibly bad idea
# objective= 95.30035 , change in objective= 0.8964462
# --------
# warning - encoder run - possibly bad idea
# objective= 93.00525 , change in objective= 2.2950974
# --------
# warning - encoder run - possibly bad idea
# objective= 92.18568 , change in objective= 0.81957245
# --------
# warning - encoder run - possibly bad idea
# objective= 91.32376 , change in objective= 0.8619156
# --------
# warning - encoder run - possibly bad idea
# objective= 90.60909 , change in objective= 0.7146683
# --------
# warning - encoder run - possibly bad idea
# objective= 91.89074 , change in objective= 1.2816467
# --------
# warning - encoder run - possibly bad idea
# objective= 89.77512 , change in objective= 2.1156158
# --------
# warning - encoder run - possibly bad idea
# objective= 89.62365 , change in objective= 0.151474
# --------
# warning - encoder run - possibly bad idea
# objective= 88.9514 , change in objective= 0.67224884
# --------
# warning - encoder run - possibly bad idea
# objective= 87.49707 , change in objective= 1.4543304
# --------
# warning - encoder run - possibly bad idea
# objective= 87.67871 , change in objective= 0.18164062
# --------
# warning - encoder run - possibly bad idea
# objective= 86.06942 , change in objective= 1.6092911
# --------
# warning - encoder run - possibly bad idea
# objective= 85.848976 , change in objective= 0.22044373
# --------
# warning - encoder run - possibly bad idea
# objective= 85.06029 , change in objective= 0.78868866
# --------
# warning - encoder run - possibly bad idea
# objective= 85.050385 , change in objective= 0.009902954
# --------
# warning - encoder run - possibly bad idea
# objective= 84.75568 , change in objective= 0.29470825
# --------
# warning - encoder run - possibly bad idea
# objective= 83.28568 , change in objective= 1.4699936
# --------
# warning - encoder run - possibly bad idea
# objective= 83.34371 , change in objective= 0.058029175
# --------
# warning - encoder run - possibly bad idea
# objective= 83.04537 , change in objective= 0.29833984
# --------
# warning - encoder run - possibly bad idea
# objective= 82.63011 , change in objective= 0.41526031
# --------
# warning - encoder run - possibly bad idea
# objective= 81.36556 , change in objective= 1.2645493
# --------
# warning - encoder run - possibly bad idea
# objective= 81.575806 , change in objective= 0.21024323
# --------
# warning - encoder run - possibly bad idea
# objective= 81.47098 , change in objective= 0.10482788
# --------
# warning - encoder run - possibly bad idea
# objective= 80.116196 , change in objective= 1.3547821
# --------
# warning - encoder run - possibly bad idea
# objective= 80.07525 , change in objective= 0.04094696
# --------
# warning - encoder run - possibly bad idea
# objective= 78.95487 , change in objective= 1.1203766
# --------
# warning - encoder run - possibly bad idea
# objective= 78.679855 , change in objective= 0.27501678
# --------
# warning - encoder run - possibly bad idea
# objective= 78.30139 , change in objective= 0.37846375
# --------
# warning - encoder run - possibly bad idea
# objective= 78.98587 , change in objective= 0.68447876
# --------
# warning - encoder run - possibly bad idea
# objective= 77.82505 , change in objective= 1.16082
# --------
# warning - encoder run - possibly bad idea
# objective= 77.60464 , change in objective= 0.22041321
# --------
# warning - encoder run - possibly bad idea
# objective= 78.30605 , change in objective= 0.701416
# --------
# warning - encoder run - possibly bad idea
# objective= 76.66356 , change in objective= 1.6424942
# --------
# warning - encoder run - possibly bad idea
# objective= 76.68538 , change in objective= 0.021820068
# --------
# warning - encoder run - possibly bad idea
# objective= 75.94961 , change in objective= 0.7357712
# --------
# warning - encoder run - possibly bad idea
# objective= 75.27949 , change in objective= 0.67012024
# --------
# warning - encoder run - possibly bad idea
# objective= 75.638336 , change in objective= 0.35884857
# --------
# warning - encoder run - possibly bad idea
# objective= 75.675476 , change in objective= 0.037139893
# --------
# warning - encoder run - possibly bad idea
# objective= 74.7843 , change in objective= 0.8911743
# --------
# warning - encoder run - possibly bad idea
# objective= 74.13842 , change in objective= 0.64588165
# --------
# warning - encoder run - possibly bad idea
# objective= 74.92619 , change in objective= 0.78777313
# --------
# warning - encoder run - possibly bad idea
# objective= 74.11499 , change in objective= 0.811203
# --------
# warning - encoder run - possibly bad idea
# objective= 74.09502 , change in objective= 0.019973755
# --------
# warning - encoder run - possibly bad idea
# objective= 73.66699 , change in objective= 0.4280243
# --------
# warning - encoder run - possibly bad idea
# objective= 72.82849 , change in objective= 0.838501
# --------
# warning - encoder run - possibly bad idea
# objective= 72.4783 , change in objective= 0.3501892
# --------
# warning - encoder run - possibly bad idea
# objective= 72.43083 , change in objective= 0.047470093
# --------
# warning - encoder run - possibly bad idea
# objective= 72.28993 , change in objective= 0.14089966
# --------
# warning - encoder run - possibly bad idea
# objective= 71.90778 , change in objective= 0.38214874
# --------
# warning - encoder run - possibly bad idea
# objective= 71.934204 , change in objective= 0.026420593
# --------
# warning - encoder run - possibly bad idea
# objective= 71.39883 , change in objective= 0.5353775
# --------
# warning - encoder run - possibly bad idea
# objective= 70.83926 , change in objective= 0.5595703
# --------
# warning - encoder run - possibly bad idea
# objective= 71.242004 , change in objective= 0.4027481
# --------
# warning - encoder run - possibly bad idea
# objective= 71.64101 , change in objective= 0.39900208
# --------
# warning - encoder run - possibly bad idea
# objective= 70.98189 , change in objective= 0.65911865
# --------
# warning - encoder run - possibly bad idea
# objective= 70.74935 , change in objective= 0.23253632
# --------
# warning - encoder run - possibly bad idea
# objective= 70.19859 , change in objective= 0.55075836
# --------
# warning - encoder run - possibly bad idea
# objective= 70.05994 , change in objective= 0.13865662
# --------
# warning - encoder run - possibly bad idea
# objective= 69.82761 , change in objective= 0.23233032
# --------
# warning - encoder run - possibly bad idea
# objective= 70.16679 , change in objective= 0.33918
# --------
# warning - encoder run - possibly bad idea
# objective= 69.34683 , change in objective= 0.8199539
# --------
# warning - encoder run - possibly bad idea
# objective= 68.986885 , change in objective= 0.3599472
# --------
# warning - encoder run - possibly bad idea
# objective= 69.90945 , change in objective= 0.92256165
# --------
# warning - encoder run - possibly bad idea
# objective= 68.83803 , change in objective= 1.0714188
# --------
# warning - encoder run - possibly bad idea
# objective= 68.502365 , change in objective= 0.33566284
# --------
# warning - encoder run - possibly bad idea
# objective= 68.4738 , change in objective= 0.028564453
# --------
# warning - encoder run - possibly bad idea
# objective= 68.50458 , change in objective= 0.030776978
# --------
# warning - encoder run - possibly bad idea
# objective= 68.20297 , change in objective= 0.30160522
# --------
# warning - encoder run - possibly bad idea
# objective= 68.11833 , change in objective= 0.0846405
# --------
# warning - encoder run - possibly bad idea
# objective= 68.06701 , change in objective= 0.051322937
# --------
# warning - encoder run - possibly bad idea
# objective= 67.64015 , change in objective= 0.426857
# --------
# warning - encoder run - possibly bad idea
# objective= 67.0225 , change in objective= 0.6176529
# --------
# warning - encoder run - possibly bad idea
# objective= 67.161736 , change in objective= 0.13923645
# --------
# warning - encoder run - possibly bad idea
# objective= 67.12401 , change in objective= 0.037727356
# --------
# warning - encoder run - possibly bad idea
# objective= 67.37927 , change in objective= 0.25526428
# --------
# warning - encoder run - possibly bad idea
# objective= 67.105995 , change in objective= 0.27327728
# --------
# warning - encoder run - possibly bad idea
# objective= 67.581985 , change in objective= 0.4759903
# --------
# warning - encoder run - possibly bad idea
# objective= 66.046265 , change in objective= 1.5357208
# --------
# warning - encoder run - possibly bad idea
# objective= 65.918945 , change in objective= 0.12731934
# --------
# warning - encoder run - possibly bad idea
# objective= 66.26441 , change in objective= 0.3454666
# --------
# warning - encoder run - possibly bad idea
# objective= 65.79669 , change in objective= 0.46772003
# --------
# warning - encoder run - possibly bad idea
# objective= 66.15339 , change in objective= 0.35669708
# --------
# warning - encoder run - possibly bad idea
# objective= 66.33492 , change in objective= 0.18153381
# --------
# warning - encoder run - possibly bad idea
# objective= 65.65813 , change in objective= 0.67679596
# --------
# warning - encoder run - possibly bad idea
# objective= 65.89737 , change in objective= 0.23924255
# --------
# warning - encoder run - possibly bad idea
# objective= 65.11465 , change in objective= 0.7827225
# --------
# warning - encoder run - possibly bad idea
# objective= 65.25553 , change in objective= 0.1408844
# --------
# warning - encoder run - possibly bad idea
# objective= 64.98479 , change in objective= 0.27074432
# --------
# warning - encoder run - possibly bad idea
# objective= 64.98267 , change in objective= 0.0021133423
# --------
# warning - encoder run - possibly bad idea
# objective= 64.97669 , change in objective= 0.0059814453
# --------
# warning - encoder run - possibly bad idea
# objective= 64.44247 , change in objective= 0.53422546
# --------
# warning - encoder run - possibly bad idea
# objective= 64.533676 , change in objective= 0.09120941
# --------
# warning - encoder run - possibly bad idea
# objective= 64.4825 , change in objective= 0.05117798
# --------
# warning - encoder run - possibly bad idea
# objective= 64.58493 , change in objective= 0.10243225
# --------
# warning - encoder run - possibly bad idea
# objective= 64.03694 , change in objective= 0.5479889
# --------
# warning - encoder run - possibly bad idea
# objective= 64.2369 , change in objective= 0.1999588
# --------
# warning - encoder run - possibly bad idea
# objective= 64.195076 , change in objective= 0.04182434
# --------
# warning - encoder run - possibly bad idea
# objective= 64.00053 , change in objective= 0.19454956
# --------
# warning - encoder run - possibly bad idea
# objective= 63.682693 , change in objective= 0.31783295
# --------
# warning - encoder run - possibly bad idea
# objective= 63.350037 , change in objective= 0.33265686
# --------
# warning - encoder run - possibly bad idea
# objective= 63.68432 , change in objective= 0.33428192
# --------
# warning - encoder run - possibly bad idea
# objective= 63.444656 , change in objective= 0.23966217
# --------
# warning - encoder run - possibly bad idea
# objective= 63.24713 , change in objective= 0.19752502
# --------
# warning - encoder run - possibly bad idea
# objective= 63.30325 , change in objective= 0.05611801
# --------
# warning - encoder run - possibly bad idea
# objective= 63.26022 , change in objective= 0.043029785
# --------
# warning - encoder run - possibly bad idea
# objective= 62.950397 , change in objective= 0.30982208
# --------
# warning - encoder run - possibly bad idea
# objective= 63.008644 , change in objective= 0.058246613
# --------
# warning - encoder run - possibly bad idea
# objective= 63.163235 , change in objective= 0.1545906
# --------
# warning - encoder run - possibly bad idea
# objective= 62.6331 , change in objective= 0.5301361
# --------
# warning - encoder run - possibly bad idea
# objective= 62.78511 , change in objective= 0.15201187
# --------
# warning - encoder run - possibly bad idea
# objective= 62.707546 , change in objective= 0.07756424
# --------
# warning - encoder run - possibly bad idea
# objective= 62.32706 , change in objective= 0.38048553
# --------
# warning - encoder run - possibly bad idea
# objective= 62.326317 , change in objective= 0.00074386597
# --------

# %%
model.print(key)
mod.printVI()
mod.printOLS()
# Out:
# --------------------------------
# Mean of the parameter distributions: mu = Traced<ConcreteArray([0.90356594 1.9651936  2.9988294 ])>with<JVPTrace(level=1/0)>
# Var of the parameter distributions: sigma^2 = Traced<ConcreteArray([0.11506568 0.03111338 0.03701368])>with<JVPTrace(level=1/0)>
# Std deviation of the parameter distributions: sigma = Traced<ConcreteArray([0.3392133  0.17638986 0.1923894 ])>with<JVPTrace(level=1/0)>
# phi = Traced<ConcreteArray([[ 0.90356594 -2.1622522 ]
#  [ 1.9651936  -3.4701173 ]
#  [ 2.9988294  -3.2964678 ]])>with<JVPTrace(level=1/0)>
# warning - encoder run - possibly bad idea
# loss= Traced<ConcreteArray(62.126972)>with<JVPTrace(level=1/0)>
# ---------------------------------
# ---------- VI summary -------------
# Optimal variational estimates of mu=  [0.90504336 1.9660599  2.9988465 ]
# Optimal variational estimates of sigma^2 =  [0.009999   0.0024832  0.00297975]
# Optimal variational loss = 49.389194
# ------------------------------------
# ---------- OLS summary -------------
# Least squares parameter estimate=  [0.9051655 1.9661201 2.9989383]
# marginal variance estimates =  [0.01042778 0.00258431 0.00298595]
# Residual sum of squares= 79.2222
# ------------------------------------

# %%
#print(np.sum((y-X@ beta_GD)**2))

# %%
#TRY USING THE SAME RANDOM NUMBERS.

phi=np.array((1.,1.,1.,1.))

model_NR = VAE(x, y,S=5000, phi0=phi)
dphi_vae = value_and_grad(model_NR.loss)
H = hessian(model_NR.loss)

obj=1000
dobj=1000

while dobj >10e-2:
    key, *subkeys = random.split(key, 3)
    obj_new, gra = dphi_vae(phi, subkeys[0])
    print('gradient=', gra)
    H = H_vae(phi, subkeys[1])  #should I use the same subkey as for the gradient???
    phinew = phi - 0.2*np.linalg.inv(H) @ gra
    print('hessian = ', H)

    phi=phinew
    model_NR.encoder(phi)
    dobj = np.abs(obj-obj_new)
    obj=obj_new
    print('objective=',obj, ', change in objective=', dobj)
    print('--------')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a62882765e14> in <module>
#       3 phi=np.array((1.,1.,1.,1.))
#       4
# ----> 5 model_NR = VAE(x, y,S=5000, phi0=phi)
#       6 dphi_vae = value_and_grad(model_NR.loss)
#       7 H = hessian(model_NR.loss)
#
# NameError: name 'x' is not defined

# %%
model.print()
phi_NR = model.phi
phi_NR

# %%
phi=np.array((1.,1.,1.,1.))

model_GD = VAE(x, y,S=5000, phi0=phi)
dphi_vae = value_and_grad(model_GD.loss)



obj=1000
dobj=1000
gamma=0.01

while dobj >10e-3:
    key, *subkeys = random.split(key, 2)
    obj_new, gra = dphi_vae(phi, subkeys[0])
    print('gradient=', gra)
    phinew = phi - gamma*  gra

    phi=phinew
    model_GD.encoder(phi)
    dobj = np.abs(obj-obj_new)
    obj=obj_new
    print('objective=',obj, ', change in objective=', dobj)
    print('--------')

phi_GD=phi

# %%
print('gradient descent estimate: ', phi_GD)
print('Newton Raphson estimate: ', phi_NR)

# %%
print('Optimized values=',model_GD.mua, model_GD.vara, model_GD.mub, model_GD.varb)
print('Optimized values=',model_NR.mua, model_NR.vara, model_NR.mub, model_NR.varb)

# %% [markdown]
# Is it crashing because of the Newton Method?? Would SGD work?

# %% [markdown]
# Fitted sum of squares

# %%
print(np.sum((y-X@betahat)**2))

beta_GD = np.array((model.mub, model.mua))
print(np.sum((y-X@ beta_GD)**2))

# %%
print(beta_GD)
print(betahat)

# %% [markdown]
# ### To do
#
# - Why do the variances look wrong? Is it just you need the tolerance low enough.... they are a relatively minor contribution to ELBO. So we need to get quite close to the optima to learn them well.
#
# - Code adam or something more sensible for the optimization.
#
# - Code Bayes
